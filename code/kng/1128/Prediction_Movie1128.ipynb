# %% [markdown]
# # ◼영화 관람객 수 예측

# %% [markdown]
# ## ◾개요

# %% [markdown]
# - 2011~2019년 영화 데이터를 이용해 영화 관람객 수 예측 모델 구현
# - 해당 모델을 2020년 영화에 적용하여 코로나19의 영향이 없었을 경우 관람객 수 예측
# - 해당 결과를 바탕으로 2020년의 영화들에 끼친 코로나19의 영향을 확인해보려한다.

# %% [markdown]
# ## ◾데이터 소개

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 영화 데이터

# %% [markdown]
# - KOBIS 공식 통계 : https://www.kobis.or.kr/kobis/business/stat/offc/searchOfficHitTotList.do?searchMode=year
# - 한국영화연감(1971~2010) 통계를 기준으로 정리한 것이며, 2011년부터는 통합전산망을 기준으로 일정한 주기(매월, 매년)로 마감처리하여 산출되는 통계정보
#   - 통합전산망을 사용한 2011년~2020년 데이터를 사용한다.
# - 컬럼 정보
#   - 순번 : 인덱스, 수치형
#   - 영화명 : 영화명, 범주형
#   - 감독 : 감독명, 범주형(다수일 경우 ', '로 구분)
#   - 제작사 : 제작사명, 범주형(다수일 경우 ', '로 구분)
#   - 수입사 : 수입사명, 범주형(다수일 경우 ', '로 구분)
#   - 배급사 : 배급사명, 범주형(다수일 경우 ', '로 구분)
#   - 개봉일 : 개봉일, 날짜형('YYYY-MM-DD')
#   - 영화유형 : 영화 유형, 범주형
#   - 영화형태 : 영화 형태, 범주형('장편', '단편', '옴니버스')
#   - 국적 : 영화 제작 국가, 범주형
#   - 전국스크린수 : 개봉 첫 주 최대 스크린 수, 수치형
#   - 전국매출액 : 전국 매출액, 수치형
#   - 전국관객수 : 전국 관객수, 수치형
#   - 서울매출액 : 서울 매출액, 수치형
#   - 서울관객수 : 서울 관객수, 수치형
#   - 장르 : 대표 장르, 범주형
#     - 21개의 유형(<a href = 'https://www.kobis.or.kr/kobis/business/stat/online/onlineGenreStat.do?CSRFToken=yOhFhXI1uvJrdJ_SERa8YxZhVjS9tKCERgIId5CsBXA&loadEnd=0&searchType=search&sSearchYearFrom=2021&sSearchMonthFrom=02&sSearchYearTo=2021&sSearchMonthTo=08' target='_blink'>KOBIS 장르별 통계 기준</a>)
#     - SF, 가족, 공연, 공포(호러), 기타, 다큐멘터리, 드라마, 멜로/로맨스, 뮤지컬, 미스터리, 범죄, 사극, 서부극(웨스턴), 성인물(에로) ,스릴러, 애니메이션, 액션, 어드벤처, 전쟁, 코미디, 판타지
#   - 등급 : 영화 시청 등급, 범주형
#   - 영화구분 : 영화 구분, 범주형('일반 영화', '독립/예술영화')

# %%
movie = pd.read_excel('../data/전체영화데이터.xls', index_col=0)
movie.head(3)
# Out:
#           영화명   감독                              제작사  수입사            배급사  \
# 순번
# 1          명량  김한민                        (주)빅스톤픽쳐스  NaN      (주)씨제이이엔엠
# 2        극한직업  이병헌  (주)어바웃필름,영화사 해그림 주식회사,(주)씨제이이엔엠  NaN      (주)씨제이이엔엠
# 3   신과함께-죄와 벌  김용화           리얼라이즈픽쳐스(주),(주)덱스터스튜디오  NaN  롯데쇼핑㈜롯데엔터테인먼트
#
#           개봉일  영화유형 영화형태  국적  전국스크린수         전국매출액     전국관객수         서울매출액  \
# 순번
# 1  2014-07-30  개봉영화   장편  한국    1587  135748398910  17613682  3.312123e+10
# 2  2019-01-23  개봉영화   장편  한국    1978  139647979516  16264944  3.185866e+10
# 3  2017-12-20  개봉영화   장편  한국    1912  115698654137  14410754  2.753083e+10
#
#       서울관객수   장르        등급  영화구분
# 순번
# 1   4163666   사극  15세이상관람가  일반영화
# 2   3638287  코미디  15세이상관람가  일반영화
# 3   3346172  판타지  12세이상관람가  일반영화

# %% [markdown]
# #### 네이버 영화 데이터

# %% [markdown]
# - 네이버 영화 검색 결과
# - 컬럼 정보
#   - 순번 : 인덱스, 수치형
#   - 영화명 : 영화명, 범주형
#   - 주연배우 : 주연배우, 범주형(복수의 경우 콤마(,)로 구분)
#   - 평점 : 영화 평균 평점, 수치형
#   - 평가자수 : 영화 평점 평가자 수, 수치형
#   - 상영시간 : 영화 상영 시간, 수치형

# %%
naver_movie = pd.read_excel('../data/네이버_영화_데이터.xlsx', index_col=0)
naver_movie.head(3)
# Out:
#     영화명        감독                                               주연배우    평점  \
# 0    33  패트리시아 리건             ['안토니오 반데라스', ' 로드리고 산토로', ' 줄리엣 비노쉬']  8.56
# 1   800        관후  ['어우 하오', ' 두순', ' 장유호', ' 당예흔', ' 강무', ' 야오천'...  3.40
# 2  1917     샘 멘데스                            ['조지 맥케이', ' 딘-찰스 채프먼']  8.89
#
#    평가자수  상영시간
# 0   241   126
# 1   693   149
# 2  6279   119

# %% [markdown]
# ## ◾데이터 분석

# %%
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import set_matplotlib_korean
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# Korean OK in your Windwos !!!

# %% [markdown]
# ### 1. 영화 데이터

# %% [markdown]
# #### 영화 데이터 결측치

# %% [markdown]
# - 2011 ~ 2020년 총 13308개의 데이터
# - 결측치가 있는 컬럼을 확인하여 결측치를 확인해본다.

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13308 entries, 1 to 13308
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   영화명     13308 non-null  object
#  1   감독      12619 non-null  object
#  2   제작사     3941 non-null   object
#  3   수입사     9095 non-null   object
#  4   배급사     13292 non-null  object
#  5   개봉일     13308 non-null  datetime64[ns]
#  6   영화유형    13308 non-null  object
#  7   영화형태    13307 non-null  object
#  8   국적      13308 non-null  object
#  9   전국스크린수  13308 non-null  int64
#  10  전국매출액   13308 non-null  int64
#  11  전국관객수   13308 non-null  int64
#  12  서울매출액   13302 non-null  float64
#  13  서울관객수   13308 non-null  int64
#  14  장르      13238 non-null  object
#  15  등급      13308 non-null  object
#  16  영화구분    13308 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(11)
# memory usage: 1.8+ MB

# %% [markdown]
# - 제작사, 수입사, 배급사 결측치
#   - 제작사, 수입사의 경우 결측치가 많으므로 배급사를 대표값으로 사용한다.
#   - 제작사, 수입사 컬럼은 삭제한다.
# - 감독, 장르, 배급사, 영화 형태의 결측치는 '기타'로 대체한다.
# - 서울매출액, 서울관객수 컬럼은 삭제한다.

# %%
movie.isnull().sum()
# Out:
# 영화명          0
# 감독         689
# 제작사       9367
# 수입사       4213
# 배급사         16
# 개봉일          0
# 영화유형         0
# 영화형태         1
# 국적           0
# 전국스크린수       0
# 전국매출액        0
# 전국관객수        0
# 서울매출액        6
# 서울관객수        0
# 장르          70
# 등급           0
# 영화구분         0
# dtype: int64

# %%
# 결측치 처리
movie = movie.drop(['제작사', '수입사'], axis=1)
movie = movie.drop(['서울매출액', '서울관객수'], axis=1)
movie['감독'].fillna('기타', inplace=True)
movie['장르'].fillna('기타', inplace=True)
movie['배급사'].fillna('기타', inplace=True)
movie['영화형태'].fillna('기타', inplace=True)

# %%
movie.isnull().sum()
# Out:
# 영화명       0
# 감독        0
# 배급사       0
# 개봉일       0
# 영화유형      0
# 영화형태      0
# 국적        0
# 전국스크린수    0
# 전국매출액     0
# 전국관객수     0
# 장르        0
# 등급        0
# 영화구분      0
# dtype: int64

# %%
# 데이터 임시 저장
# movie.to_excel('../data/전체영화데이터_1_fillna.xls', encoding='utf-8')
# xlwt의 유지보수가 끝나 사용이 종료된다고 한다. 으악

# import openpyxl
# openpyxl 사용 코드 예시를 첨부한다.
# writer = pd.ExcelWriter("../data/test.xls", engine='openpyxl', date_format='YYYY-MM-DD')
# movie.to_excel(writer)
# writer.close()

# %% [markdown]
# #### 영화 데이터 범주형 확인

# %% [markdown]
# - 데이터 유형
#   - 날짜형(1개) : 개봉일('YYYY-MM-DD')
#   - 수치형(3개) : 전국스크린수, 전국매출액, 전국관객수
#   - 범주형(9개) : 영화명, 감독, 배급사, 영화유형, 영화형태, 국적, 장르, 등급, 영화구분
# - 범주형 데이터 중복 확인한 결과 영화명을 제외하고 중복값이 많은 것을 볼 수 있다.
# - 각 범주형을 살펴보며 데이터 정리를 진행한다.

# %%
category_cols = ['영화명','감독','배급사','영화유형','영화형태','국적','장르','등급','영화구분',]

# 범주형 데이터의 unique 확인
for col in category_cols:
    print('컬럼 [{}] UNIQUE : {}'.format(col, len(movie[col].unique())))
# Out:
# 컬럼 [영화명] UNIQUE : 13116
# 컬럼 [감독] UNIQUE : 6131
# 컬럼 [배급사] UNIQUE : 905
# 컬럼 [영화유형] UNIQUE : 1
# 컬럼 [영화형태] UNIQUE : 4
# 컬럼 [국적] UNIQUE : 68
# 컬럼 [장르] UNIQUE : 21
# 컬럼 [등급] UNIQUE : 10
# 컬럼 [영화구분] UNIQUE : 2

# %% [markdown]
# ##### 1. 감독

# %% [markdown]
# - 감독 데이터
#   - 다수의 감독이 있는 경우 콤마(,)로 구분되어 있다.
#   - 다수의 감독을 분리하여 1명의 대표감독으로 변경해준다.
#     - ','를 기준으로 분리 오름차순 정렬 후 첫 번째 감독을 사용
#     - `'안소니 루소,조 루소'`-`'조 루소, 안소니 루소'`와 같은 형태가 존재하기에 정렬을 진행한다.

# %%
movie['감독'].unique()
# Out:
# array(['김한민', '이병헌', '김용화', ..., '오카다 히로', '허재형', '레 탄 선'], dtype=object)

# %%
# 다수의 감독 데이터 변경
for idx, row in movie.iterrows():
    if ',' in row['감독']:
        directors = row['감독'].split(',')
        # 양 끝 공백 제거 후 정렬
        directors.sort(key=lambda x : x.strip())
        movie['감독'][idx] = directors[0].strip()

# %% [markdown]
# - 대표 감독 선정으로 5987 개로 정리되었다.

# %%
len(movie['감독'].unique()), movie['감독'].unique()
# Out:
# (5987,
#  array(['김한민', '이병헌', '김용화', ..., '오카다 히로', '허재형', '레 탄 선'], dtype=object))

# %% [markdown]
# ##### 2. 배급사

# %% [markdown]
# - 배급사 데이터
#   - 다수의 배급사가 있는 경우 콤마(,)로 구분되어 있다.
#   - 다수의 배급사를 분리하여 1개의 대표배급사로 변경해준다.
#     - 가장 처음 나오는 배급사 이름이 가장 중요하다고 판단하여 해당 배급사를 대표배급사로 결정한다.

# %%
movie['배급사'].unique()
# Out:
# array(['(주)씨제이이엔엠', '롯데쇼핑㈜롯데엔터테인먼트', '월트디즈니컴퍼니코리아 유한책임회사', '(주)쇼박스',
#        '(주)넥스트엔터테인먼트월드(NEW)', '롯데컬처웍스(주)롯데엔터테인먼트',
#        '월트디즈니컴퍼니코리아 유한책임회사,월트디즈니컴퍼니코리아(주)', '소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)',
#        '워너브러더스 코리아(주)', '월트디즈니컴퍼니코리아 유한책임회사,이십세기폭스코리아(주)',
#        '월트디즈니컴퍼니코리아(주)', '(주)씨제이이엔엠,(주)덱스터스튜디오',
#        '소니픽쳐스엔터테인먼트코리아주식회사극장배급지점',
#        '월트디즈니컴퍼니코리아 유한책임회사,한국소니픽쳐스릴리징브에나비스타영화㈜', '이십세기폭스코리아(주)',
#        '메가박스중앙(주)플러스엠,(주)키위미디어그룹', '유니버설픽쳐스인터내셔널 코리아(유)',
#        '한국소니픽쳐스릴리징브에나비스타영화㈜', 'CGV아트하우스,(주)대명문화공장',
#        '롯데쇼핑㈜롯데엔터테인먼트,(주)싸이더스', '메가박스중앙(주)플러스엠', '판씨네마(주)', '(주)와우픽쳐스',
#        '(주)에이스메이커무비웍스,(주)키위미디어그룹', '롯데쇼핑㈜롯데엔터테인먼트,(주)리틀빅픽쳐스',
#        '(주)스튜디오디에이치엘,주식회사 해리슨앤컴퍼니,워너브러더스 코리아(주)', '아이러브시네마',
#        '(주)인벤트스톤,영화사청어람(주)', '(주)에이스메이커무비웍스', '필라멘트픽쳐스',
#        '오퍼스픽쳐스(유),CGV아트하우스', '에스케이플래닛(주),(주)씨제이이엔엠', '씨네그루(주)다우기술',
#        '(주)메리크리스마스,TCO(주)더콘텐츠온', 'CJ ENM', 'CGV아트하우스,영화사 풀',
#        '(주)제이앤씨미디어그룹,TCO(주)더콘텐츠온', '씨너스엔터테인먼트(주),타임스토리그룹(주)',
#        '(주)영화사 그램,이십세기폭스코리아(주)', 'CGV아트하우스', '주식회사 해리슨앤컴퍼니,이십세기폭스코리아(주)',
#        '워터홀컴퍼니(주),(주)쇼박스', '메가박스중앙(주)플러스엠,주식회사 키위컴퍼니', '(주)키다리이엔티',
#        '(주)디스테이션,(주)시너지하우스 (시너지),롯데쇼핑㈜롯데엔터테인먼트', '씨너스엔터테인먼트(주)',
#        '(주)시너지하우스 (시너지),롯데쇼핑㈜롯데엔터테인먼트', '메가박스중앙(주)플러스엠,(주)콘텐츠 난다긴다',
#        '(주)에스비에스콘텐츠허브', '(주)누리픽쳐스', '글뫼 주식회사,이십세기폭스코리아(주)',
#        '(주)넥스트엔터테인먼트월드(NEW),(주)씨제이이엔엠', '(주)시네마서비스,(주)나이너스엔터테인먼트',
#        '(주)스마일이엔티', '소니픽쳐스엔터테인먼트코리아주식회사극장배급지점,(주)키다리이엔티', '(주)올스타엔터테인먼트',
#        '(주)화앤담이엔티', '(주)리틀빅픽쳐스', '(주)쇼박스,(주)와우픽쳐스',
#        '(주)피터팬픽쳐스,이십세기폭스코리아(주)', '롯데쇼핑㈜롯데엔터테인먼트,(주)스마일이엔티', '오퍼스픽쳐스(유)',
#        '롯데컬처웍스(주)롯데엔터테인먼트,(주)키다리이엔티', '메가박스중앙(주)플러스엠,(주)미디어캐슬,워터홀컴퍼니(주)',
#        '(주)미디어데이', '메가박스중앙(주)플러스엠,(주)리틀빅픽쳐스', '(주)싸이더스', '유나이티드픽처스(주)',
#        '주식회사 우리네트웍스', '(주)나이너스엔터테인먼트', '(주)이수C&E', '(주)메리크리스마스',
#        '(주)제이앤씨미디어그룹', '(주)엣나인필름', '(주)스마일이엔티,(주)에스비에스콘텐츠허브',
#        'TCO(주)더콘텐츠온,(주)제이앤씨미디어그룹', '판씨네마(주),(주)프레인글로벌', '영화사올(주)',
#        '(주)콘텐츠 난다긴다', '롯데쇼핑㈜롯데엔터테인먼트,(주)마인스 엔터테인먼트',
#        '(주)싸이더스,(주)넥스트엔터테인먼트월드(NEW)', '(주)시너지하우스 (시너지)',
#        '(주)리틀빅픽쳐스,(주)트리니티픽쳐스', '(주)마인스 엔터테인먼트,(주)박수엔터테인먼트', '오드,(주)홈초이스',
#        '주식회사 마운틴픽쳐스,(주)마인스 엔터테인먼트', '(주)스튜디오디에이치엘,판씨네마(주)', '오드',
#        '(주)리틀빅픽쳐스,(주)이수C&E', '(주)시네마서비스', '(주)키다리이엔티,주식회사 키위컴퍼니',
#        '(주)팝엔터테인먼트', '(주)디스테이션,(주)드림팩트엔터테인먼트,(주)나이너스엔터테인먼트',
#        '주식회사 더쿱,유니버설픽쳐스인터내셔널 코리아(유)', '씨제이 씨지브이(CJ CGV)(주)',
#        'CGV ICECON,월트디즈니컴퍼니코리아 유한책임회사', '씨너스엔터테인먼트(주),(주)엣나인필름',
#        '(주)프레인글로벌', '(주)삼백상회,(주)키다리이엔티', '(주)스마일이엔티,씨네그루(주)다우기술',
#        '(주)리틀빅픽쳐스,(주)대명문화공장', '(주)박수엔터테인먼트', '타임스토리그룹(주)', '(주)팝파트너스',
#        '(재)CBS,주식회사 마운틴픽쳐스', '예지림엔터테인먼트', '(주)디스테이션', '(재)CBS',
#        'CGV아트하우스,그린나래미디어(주)', '(주)인벤트스톤', '(주)영화사 빅', '(주)홈초이스',
#        '㈜코리아스크린', 'CGV아트하우스,(주)리틀빅픽쳐스', '(주)그노스', '(주)이놀미디어',
#        '(주)와우픽쳐스,(주)쇼박스', '(주)까멜리아이엔티,(주)팝엔터테인먼트',
#        '(주)영화사 그램,(주)제이앤씨미디어그룹,(주)팝파트너스',
#        '(주)디스테이션,소니픽쳐스엔터테인먼트코리아주식회사극장배급지점', '(주)모멘텀엔터테인먼트',
#        '(주)키위미디어그룹,오퍼스픽쳐스(유),(주)씨네필운', '(주)넥스트엔터테인먼트월드(NEW),판씨네마(주)',
#        '(주)팝엔터테인먼트,(주)나이너스엔터테인먼트', '(주)티캐스트', '메가박스중앙(주)플러스엠,(주)레드로버',
#        '(주)셀트리온엔터테인먼트', '(주)대명문화공장,(주)리틀빅픽쳐스', '에스케이텔레콤(주)',
#        '(주)마인스 엔터테인먼트', '에이원엔터테인먼트', '그린나래미디어(주),(주)홈초이스', '(주)영화사 진진',
#        '(주)영화사 그램', '(주)이수C&E,(주)스톰픽쳐스코리아', '(주)박수엔터테인먼트,㈜코리아스크린',
#        '(주)엣나인필름,(주)콘텐츠판다', '그린나래미디어(주),플레이리스트(주)', '㈜코리아스크린,와이드 릴리즈(주)',
#        '찬란', '와이드 릴리즈(주)', '(주)아이코닉스', '(주)콘텐츠판다', 'CGV ICECON',
#        '(주)엣나인필름,CGV아트하우스', '찬란,CGV아트하우스', '그린나래미디어(주)',
#        '(주)리틀빅픽쳐스,(주)페퍼민트앤컴퍼니', '커넥트픽쳐스(주)', '(주)티캐스트콘텐츠허브',
#        'KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', 'TCO(주)더콘텐츠온', '팝엔터테인먼트',
#        '동우에이앤이(주),(주)박수엔터테인먼트', '(주)누리픽쳐스,(주)영화특별시에스엠씨',
#        '(주)넥스트엔터테인먼트월드(NEW),KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)',
#        '(주)제이앤씨미디어그룹,(주)나이너스엔터테인먼트', '(주)삼지애니메이션', '(주)박수엔터테인먼트,(주)애니플러스',
#        '(주)지어소프트', '주식회사 마운틴픽쳐스', '블루미지', '(주)트리플픽쳐스', '(주)영화사오원',
#        '씨제이포디플렉스 주식회사', '(주)드림팩트엔터테인먼트,(주)제이앤씨미디어그룹,TCO(주)더콘텐츠온',
#        '(주)스마일이엔티,(주)영화사오원', '(주)무빙픽쳐스컴퍼니', '(주)케이티알파',
#        '롯데쇼핑㈜롯데엔터테인먼트,타임스토리그룹(주)', '파이오니아21', '(주)더블앤조이픽쳐스',
#        '(주)삼백상회,(주)팬엔터테인먼트', '(주)크리픽쳐스', '(주)누리픽쳐스,(주)케이티알파',
#        '(주)싸이더스,(주)디스테이션', '그린나래미디어(주),(주)버킷스튜디오', '(주)애니플러스',
#        '(주)드림팩트엔터테인먼트,팝엔터테인먼트', '(주)키다리이엔티,(주)삼백상회', '(주)영화사 그램,(재)CBS',
#        '기타', '(주)영화사 빅,(주)다날엔터테인먼트', '(주)라이크콘텐츠,(주)넥스트엔터테인먼트월드(NEW)',
#        '(주)영화제작전원사 ,(주)넥스트엔터테인먼트월드(NEW)', '(주)박수엔터테인먼트,에이원엔터테인먼트',
#        '(주)팝엔터테인먼트,(주)영화사 빅', '(주)리틀빅픽쳐스,(주)인벤트스톤', '(유)조이앤시네마',
#        '(주)포켓몬코리아', '(주)시네마달', '글뫼 주식회사,(주)에스와이코마드',
#        '(주)영화특별시에스엠씨,(주)콘텐츠패밀리', '(주)와이즈베이', '이언픽쳐스,씨너스엔터테인먼트(주)',
#        '(주)영화제작전원사 ,(주)영화사 조제', '(주)영화사 빅,(주)버킷스튜디오',
#        '롯데쇼핑㈜롯데엔터테인먼트,(주)시너지하우스 (시너지)', '(주)드림팩트엔터테인먼트,(주)미로스페이스',
#        '(주)스톰픽쳐스코리아,주식회사 우리네트웍스', '(주)브리즈픽처스,(주)영화사오원',
#        '주식회사 마운틴픽쳐스,(주)케이티알파', '㈜T-JOY,씨너스엔터테인먼트(주)', '(주)라이크콘텐츠',
#        '대원미디어(주)', '힘컨텐츠(주),(주)디스테이션', '(주)이수C&E,(주)에이원엔터테인먼트',
#        '그린나래미디어(주),(주)프레인글로벌', '(재)CBS,(주)영화사 안다미로',
#        '(주)팝엔터테인먼트,(주)영화사오원,(주)브리즈픽처스', '(주)쇼박스,(주)씨제이이엔엠,롯데쇼핑㈜롯데엔터테인먼트',
#        '(주)영화제작전원사 ,(주)콘텐츠판다', '(주)퍼스트런,(주)팬엔터테인먼트',
#        '(주)나이너스엔터테인먼트,(주)지어소프트', '(주)스톰픽쳐스코리아', '이언픽쳐스,(주)그란', 'THE 픽쳐스',
#        '㈜영화사 백두대간', '(주)미디어캐슬,(주)박수엔터테인먼트,에이원엔터테인먼트',
#        '(주)미디어캐슬,(주)팝엔터테인먼트', '(주)넥스트엔터테인먼트월드(NEW),(주)팬엔터테인먼트',
#        '(주)다자인소프트,(주)유로커뮤니케이션', '(주)박수엔터테인먼트,(주)모인그룹',
#        '주식회사 온 피크,스튜디오 프로그레시브 인큐베이터', '(주)스톰픽쳐스코리아,(주)페퍼민트앤컴퍼니',
#        '㈜씨에이엔,(주)엣나인필름', '(주)메인타이틀픽쳐스', '주식회사 디에스이이디', '(주)엠제이픽쳐스',
#        '(주)아이엠비씨,KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', '(주)마노엔터테인먼트',
#        '(주)메인타이틀픽쳐스,주식회사 키위컴퍼니', '(주)영화제작전원사', '(주)콘텐츠판다,TCO(주)더콘텐츠온',
#        '(주)인디플러그', '(주)대명문화공장,(주)나이너스엔터테인먼트', '(주)미로비젼',
#        '(주)인디플러그,(주)더 피플', '(주)스튜디오 보난자,(주)미로비젼', '(주)이수C&E,(주)시너지미디어',
#        '(주)더블앤조이픽쳐스,TCO(주)더콘텐츠온', '어뮤즈', '(주)미로비젼,아뮤즈코리아(주)',
#        '골든타이드픽처스(주)', '㈜영화사 백두대간,영화사 풀', '(주)두타연,(주)미디어데이',
#        '(주)스톰픽쳐스코리아,(주)이수C&E', '주식회사 마운틴픽쳐스,(주)에스와이코마드',
#        '(주)프레인글로벌,CGV아트하우스', '(주)미디어캐슬', '(주)이수C&E,(주)팝엔터테인먼트',
#        '(주)싸이더스,찬란', '(주)스톰픽쳐스코리아,(주)디스테이션', '㈜인디스토리',
#        '(주)이놀미디어,(주)드림팩트엔터테인먼트,(주)미로스페이스,씨너스엔터테인먼트(주),(주)미로비젼,(주)박수엔터테인먼트',
#        '롯데쇼핑㈜롯데엔터테인먼트,케이비에스미디어(주)', '(주)엣나인필름,씨너스엔터테인먼트(주)',
#        '(주)드림팩트엔터테인먼트', '(주)에스와이코마드,글뫼 주식회사', '(주)영화사 진진,(주)영화사 조제',
#        '(주)스톰픽쳐스코리아,(주)삼백상회', '이달투', '(주)스톰픽쳐스코리아,TCO(주)더콘텐츠온',
#        '(주)영화사오원,(주)브리즈픽처스', '(주)인벤트스톤,(주)디스테이션', '(주)에스피엠', '(주)디오시네마',
#        '브릿지웍스 엔터테인먼트(주)', '그린나래미디어(주),(주)키위미디어그룹', '(주)영화특별시에스엠씨',
#        '메가박스중앙(주)플러스엠,(주)엣나인필름', '그린나래미디어(주),주식회사 노버스엔터테인먼트',
#        '(주)머스트씨무비릴리징컴퍼니', '주식회사 더쿱', '(주)씨네포트,주식회사 마운틴픽쳐스',
#        '(주)디스테이션,(주)엔케이컨텐츠', '오드,(주)티캐스트', '(주)머스트씨무비릴리징컴퍼니,주식회사 온 피크',
#        '(주)빅웨이브시네마', '플레이리스트(주)', '아이 엠', '㈜케이디미디어', '제인앤유',
#        'THE 픽쳐스,(주)팝엔터테인먼트', '(주)팬엔터테인먼트,(주)영화특별시에스엠씨', '(주)드림웨스트픽쳐스',
#        '(주)영화사오원,(주)퍼스트런', '(주)삼백상회', '예지림엔터테인먼트,선필름', '롯데쇼핑㈜롯데시네마',
#        '(주)버킷스튜디오', '(주)좋은 하늘,(주)박수엔터테인먼트', '(주)드림팩트엔터테인먼트,(주)삼백상회',
#        'KBS 미디어', '오키넷,(주)라이크콘텐츠', '주식회사 씨네룩스', '(주)퍼스트런,(주)키다리이엔티',
#        '(주)영화사 그램,TCO(주)더콘텐츠온,(재)CBS', '(주)제이앤씨미디어그룹,(주)버킷스튜디오',
#        '영화사 마농(주)', '(주)블룸즈베리파트너스', '(주)디스테이션,플레이리스트(주)',
#        '<나쁜 나라> 배급위원회,(주)시네마달', '(주)화인픽쳐스', '주식회사 왓챠,(주)팝엔터테인먼트',
#        '(주)대교 미디어콘텐츠사업본부', '(주)아우라픽처스', '(주)디오시네마,(주)영화사 그램',
#        '(주)영화사오원,(주)프레인글로벌', '영화사 마농(주),(주)씨네클럽봉봉미엘',
#        '(주)나이너스엔터테인먼트,(유)영화사 화수분', 'TCO(주)더콘텐츠온,주식회사 더쿱', '(주)영화사조아',
#        '(주)엣나인필름,플레이리스트(주)', '(주)박수엔터테인먼트,(주)필름오마쥬', '스튜디오 프로그레시브 인큐베이터',
#        '(주)미디어로그', '주식회사 풍경소리,판씨네마(주)', '주식회사 단유필름,주식회사 푸르모디티',
#        '(주)디스테이션,롯데컬처웍스(주)롯데엔터테인먼트', '글뫼 주식회사', '(주)엣나인필름,(주)팝엔터테인먼트',
#        '(주)영화사 진진,(주)누리픽쳐스', '(주)키다리이엔티,플레이리스트(주)', '(주)명필름',
#        '(주)영화사 안다미로,오드', '(주)영화사 조제', 'TCO(주)더콘텐츠온,(주)전망좋은 영화사',
#        '(주)머스트씨무비,(주)머스트씨무비릴리징컴퍼니', '(주)영화사 안다미로,(주)팝엔터테인먼트', '데이지엔터테인먼트',
#        '(주)메타플레이', 'TCO(주)더콘텐츠온,(주)디스테이션', '영화사 풀', '(주)다자인소프트',
#        '그린나래미디어(주),(주)키다리이엔티', '(주)싸이더스,(주)삼백상회',
#        '(주)마인스 엔터테인먼트,(유)영화사 화수분', '주식회사 슈아픽처스', '(주)드림웨스트픽쳐스,(주)인벤트스톤',
#        '동우에이앤이(주)', '알토미디어(주)', '(주)에스와이코마드', '시네마 뉴원', '(주)씨에이씨엔터테인먼트',
#        '스마트스터디(주)', '(주)앤드플러스미디어웍스', '(주)머스트씨무비', '(주)팝엔터테인먼트,주식회사 더쿱',
#        '스튜디오느림보', 'TCO(주)더콘텐츠온,(유)조이앤시네마', '그린나래미디어(주),(주)다날엔터테인먼트',
#        '(주)소나무픽쳐스', '(주)중헌홀딩스', '(주)프레인글로벌,(주)스톰픽쳐스코리아', '(주)브리즈픽처스',
#        '(주)블룸즈베리리소시스리미티드', '(재)CBS,주식회사 블루필름웍스', '(주)알앤오엔터테인먼트',
#        '(주)스마일이엔티,(주)씨제이이엔엠', '(주)프레인글로벌,(주)콘텐츠판다', '프리비젼엔터테인먼트',
#        '(주)씨제이이엔엠,㈜인디스토리', '(주)팬엔터테인먼트', '(주)디지컴코리아엠앤엠', '이언픽쳐스',
#        '주식회사 블루필름웍스', '(주)이수C&E,(주)콘텐츠판다', '(주)더 피플', '(주)싸이더스,아이 엠',
#        '(주)뮤제엔터테인먼트', 'CJ ENM,씨제이 씨지브이(CJ CGV)(주)', '뉴원시네마',
#        '주식회사 더쿱,TCO(주)더콘텐츠온', '씨네21아이(주)', '(주)스톰픽쳐스코리아,와이드 릴리즈(주)',
#        '(주)엣나인필름,(주)시네마달', '주식회사 블루필름웍스,주식회사 마운틴픽쳐스,TCO(주)더콘텐츠온',
#        '(주)에이원엔터테인먼트,(주)삼지애니메이션', '스크린조이', '(주)더블앤조이픽쳐스,(주)브리즈픽처스',
#        'CGV아트하우스,(주)엣나인필름', '(주)에이원엔터테인먼트', '(주)삼지애니메이션,(주)에이원엔터테인먼트',
#        '(주)비싸이드 픽쳐스,주식회사 모쿠슈라픽쳐스,필립 스튜디오', '(주)김기덕 필름', '(주)한마음프로덕션',
#        'M&M 인터내셔널', '(주)영화사샘', '(주)키노아이디엠씨', '(주)싸이더스,무브먼트',
#        '(유)조이앤컨텐츠그룹', '워터홀컴퍼니(주)', '(주)제이앤씨미디어그룹,(주)박수엔터테인먼트',
#        'THE 픽쳐스,주식회사 마운틴픽쳐스', '(주)영화특별시에스엠씨,(주)삼백상회', '(주)필마픽쳐스',
#        '(주)영화제작전원사 ,(주)콘텐츠판다,무브먼트', '(주)영화사 안다미로', '주식회사 쇼미미디어앤트레이딩',
#        '(주)미로스페이스,주식회사 제이씨엔터웍스', '그린나래미디어(주),무브먼트', '메가박스중앙(주)', '㈜씨에이엔',
#        '(주)패뷸러스', '(주)리틀빅픽쳐스,주식회사 더쿱',
#        '(주)스톰픽쳐스코리아,TCO(주)더콘텐츠온,(주)레인메이커필름', '(주)바른손이앤에이', '에스디시코리아 주식회사',
#        '케이비에스미디어(주),KBS 미디어', '(주)영화사선', '롯데쇼핑㈜롯데엔터테인먼트,(주)퍼스트런',
#        '퍼즐엔터테인먼트', '와이드 릴리즈(주),(주)제이앤씨미디어그룹', '(주)콘텐츠판다,(주)영화제작전원사 ,무브먼트',
#        '(주)스튜디오 보난자', '(주)미로스페이스', '(주)콘텐츠판다,(주)스마일이엔티',
#        '(주)제이앤씨미디어그룹,와이드 릴리즈(주)', '(주) 인스터 글로벌',
#        '주식회사 온 피크,(주)머스트씨무비릴리징컴퍼니', '(주)퍼스트런', '(주)스크린와이즈', '(주)수키픽쳐스',
#        '노바엔터테인먼트', '케이비에스미디어(주),주식회사 마운틴픽쳐스', '(주)미로스페이스,THE 픽쳐스',
#        '(주)판다미디어', '(주)드림팩트엔터테인먼트,(주)일레븐엔터테인먼트', 'TCO(주)더콘텐츠온,플레이리스트(주)',
#        '(주)더블앤조이픽쳐스,주식회사 쇼미미디어앤트레이딩', '(주)미루픽처스', '어뮤즈,(주)엣나인필름', '하준사',
#        '(주)대명문화공장,KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', '시네마 뉴원,(주)콘텐츠윙',
#        '익스트림 필름', '(주)서태지컴퍼니', '시네마달', '주식회사 더쿱,(주)영화특별시에스엠씨', '(주)케이알씨지',
#        '영화사 민들레,주식회사 마운틴픽쳐스', '(주)컴퍼니엘', '(주)에이썸엔터테인먼트',
#        '(주)나이너스엔터테인먼트,주식회사 시온픽쳐스', '(주)영화특별시에스엠씨,주식회사 더쿱',
#        '(주)제이앤씨미디어그룹,(주)팝엔터테인먼트', '(주)영화사폴', '(주)률필름,㈜인디스토리', '(주)유비네트워크',
#        '미디어소프트,(주)뮤제엔터테인먼트', '(주)스크린다', '얼리버드', '(주)엔케이컨텐츠',
#        '주식회사 디에스이이디,(주)로카', '(주)레몬트리픽쳐스', '딥 포커스', '세븐바이투픽쳐스', '무브먼트',
#        '삼라 주식회사', 'CGV아트하우스,㈜인디스토리', '(주) 루스이소니도스',
#        '(주)디스테이션,(주)엔케이컨텐츠,(주)앤드플러스미디어웍스', '(주)영화사 그램,(주)디오시네마',
#        '(주)누리픽쳐스,(주)영화사 진진', '주식회사 드림크리에이션', '(주)미디어캐슬,(주)삼지애니메이션',
#        '아이제이미디어(주)', '(주)도키엔터테인먼트', '(주)유로커뮤니케이션', '애니메이션 배급, 씨앗,㈜인디스토리',
#        '(주)미로스페이스,(주)드림팩트엔터테인먼트', '(재)전주국제영화제조직위원회', '㈜인디스토리,(주)인디플러그',
#        '주식회사 풍경소리', 'C 무비', '(주)일레븐엔터테인먼트', '(주)로드하우스', '(주)에이블엔터테인먼트',
#        '(주)레인메이커필름', '(주)케빈앤컴퍼니', '미디어 컨텐츠 스토어,(주)인디플러그',
#        '와이드 릴리즈(주),(주)스톰픽쳐스코리아', '아이 엠,(주)케이티알파', '씨드', '미라클필름',
#        '(주)올댓시네마 플러스,(주)미로스페이스', '영화사 마그나', '㈜T-JOY,메가박스중앙(주)플러스엠',
#        '(주)디오시네마,(주)영화사 조제', '골든타이드픽처스(주),(주)영화사 조제', '(주)씨네포트',
#        '(주)라온컴퍼니플러스', '상남영화제작소', '무브먼트,영화배급협동조합 씨네소파', '영화사 풀,(주)영화사 친구',
#        '(주)마인스 엔터테인먼트,주식회사 마운틴픽쳐스', '(주)디스테이션,(주)브리즈픽처스',
#        '홀리가든,주식회사 마운틴픽쳐스', '52DAYS FILM', '(유)영화사 화수분', '(주)쓰리캣프로덕션',
#        '(주)도키엔터테인먼트,예지림엔터테인먼트', '(주)오렌지옐로우하임,홀리가든', '다솔기획,(주)추억을 파는 극장',
#        '데이브인터랙티브', '위드 라이언 픽쳐스', '(주)까멜리아이엔티', '(주)영화사메이플러스,주식회사 마운틴픽쳐스',
#        '(주)따미픽쳐스', '서울독립영화제', '퓨어웨이픽쳐스', '예지림엔터테인먼트,미디어소프트', '(주)트리필름',
#        '필름메신저', '(주)민치앤필름', '무브먼트,영화사 몸', '호우주의보',
#        '주식회사 마운틴픽쳐스,(주)팝엔터테인먼트', '(주)노바이앤티', '서울독립영화제,무브먼트', '윤스',
#        '팝엔터테인먼트,(주)영화사조아', '(주)키다리이엔티,(주)스마일이엔티', '(사)필레마,필름포럼,홀리가든',
#        '(주)씨네마드마농', '애니메이션 배급, 씨앗', '주식회사 세미콜론스튜디오', '(주)비프로',
#        '(주)팬엔터테인먼트,(주)퍼스트런', '(주)레인보우팩토리', '영화사 무명', '홀리가든,불안한외출배급위원회',
#        '이미지팩토리', '(주)갑종무비필름', '투썸업픽쳐스', '강 컨텐츠', '롤러코스터',
#        '시네마 뉴원,(주)드림팩트엔터테인먼트', '필름에이픽쳐스', '홀리가든,(주)오렌지옐로우하임', '파인스토리',
#        '(주)퍼스트런,글뫼 주식회사', '필름다빈', '(주)액티버스엔터테인먼트',
#        'CGV ICECON,씨제이포디플렉스 주식회사', '영화사 삼순', '문화선교연구원', '(주)월드시네마',
#        '(주)맑은시네마', '(주)피터팬픽쳐스', '(주)디앤아이컴퍼니', '무브먼트,독립영화전용관 인디스페이스',
#        '스토리 너머,파인스토리', '주식회사 온 피크,(주)다날엔터테인먼트', '다큐스토리', '(주)스넵쏘울',
#        '씨너스엔터테인먼트(주),㈜T-JOY', '(주)시네마엔터,(주)모멘텀엔터테인먼트', '(주)에픽캔',
#        '(주)랠리버튼', '(주)미디어이야기', '고구마콘텐츠허브(주)', '(주)베드픽쳐스', '영희야 놀자',
#        '주식회사 왓챠', '홀리가든', '㈜크래커픽쳐스', '영화배급협동조합 씨네소파', '(주)엠레콘',
#        '(주)토러스엔터테인먼트', '(주)미로스페이스,(주)스튜디오 보난자', '씨네굿', '(주)문와쳐',
#        '주식회사 골든럭', '(주)레인메이커필름,(주)모멘텀엔터테인먼트', '팔레드시네마(주)', '어썸피플,어뮤즈',
#        'M&M 인터내셔널,(주)영화사 조제', '(주)로카', '(유)조이앤시네마,(주)제이앤씨미디어그룹',
#        '(주)영화사 안다미로,(주)수키픽쳐스', 'ZONE Film', '레드무비', '(주)자우엔터테인먼트',
#        '(주)미디어 마그나', '독포레스트', '밀크픽처스', 'CL2D Film',
#        '(주)스토리제이,(주)드림팩트엔터테인먼트', '(주)누리픽쳐스,(주)스톰픽쳐스코리아,와이드 릴리즈(주)',
#        '명필름랩', '반달', '라인트리엔터테인먼트', '(주)제이앤씨미디어그룹,(주)드림팩트엔터테인먼트',
#        '주식회사 노버스엔터테인먼트', '아방가르드 필름', '스마일픽쳐스', '퍼즐컷', '시네마서울', '엠투',
#        '(주)콘텐츠윙', '(주)아이디어랩', '제이리미디어', '주식회사 키노엔터테인먼트', '(재)영화의전당',
#        '롯데컬처웍스(주)롯데엔터테인먼트,(주)영화사 그램', '애니박스 엔터테인먼트', '매치컷(주)',
#        '모두를위한극장 공정영화협동조합', '해피송,롯데컬처웍스(주)롯데엔터테인먼트', '(주)인벤트스톤,(주)영화사오원',
#        '(주)나우콘텐츠', '페퍼민트픽쳐스', '(주)차룡영화사', '(주)팝엔터테인먼트,(주)제이엠씨미디어',
#        '(주)티앤엘엔터테인먼트', '전국예술영화관협회,에무 시네마 앤 카페', '씨네쿼넌 픽쳐스', '(주)원더스컴퍼니',
#        '(주)에이씨피컴퍼니', '시네마달,(사)한국독립영화협회', '야간비행', '(주)유어스토리블루', '길스토리',
#        '주식회사 루믹스미디어', 'THE 픽쳐스,(주)미로스페이스', '㈜스토리셋', '(주)에스와이코마드,아이 엠',
#        '(주)스튜디오후크', '와이드 릴리즈(주),필라멘트픽쳐스', '포커스 온', '㈜싸이더스픽쳐스', '일미디어',
#        '크리에이티브컴즈(주)', '제나두엔터테인먼트', '플랫폼C', '즐감', '프로젝트 엔터테인먼트',
#        '태창엔터테인먼트(주)', '주식회사 씨엠닉스', '(주)투한미디어', '미디어소프트', '(주)더그레이트컴퍼니',
#        '쟈비스미디어', '성길시네마,아이제이미디어(주)', '주식회사 마운틴픽쳐스,영화사 민들레', '영화사 보라',
#        '디에이치 컴퍼니', '(주)제이에이와이이엔터테인먼트', '글뫼 주식회사,(주)퍼스트런', '에이라인',
#        '(주)영화사히트', '마법사필름', '(주)얼리버드픽쳐스', '(주)갤럭시컴퍼니', '(주)두엔터테인먼트',
#        '골든타이드픽처스(주),(주)옐로우필름', '(주)로이테미디어', '(주)웃기씨네', '(주)우성엔터테인먼트',
#        '더사람픽쳐스', '달밤체조(주)', '(주)투윈미디어', '㈜T-JOY', '주식회사 비엠미디어',
#        '디마엔터테인먼트', '(주)마고필름', '이닥픽쳐스', '(사)독립영화전용관 확대를 위한 시민모임',
#        '(주)KW비젼', '(주)노리픽쳐스', '(주)올댓시네마 플러스', '(주)이모션픽처스', '영화사 인연',
#        '(주)케이앤엔터테인먼트', '예술의전당', '조이월드앤다이버시티', '레인메이커필름', '(주)아바엔터테인먼트',
#        '(주)26컴퍼니', '(주)제이브로', '(주)선익필름', '(주)블루브릭',
#        '(주)박수엔터테인먼트,(주)미로스페이스', '(주)영화사 사계절', '(주)인피니티엔터테인먼트', '(주)백그림',
#        '이상우필름', '(유)쏘아필름', '봄바람영화사', '(주)에이앤비픽쳐스', '씨네마캣 픽쳐스',
#        '(주)H.F.G엔터테인먼트', '크리스리픽쳐스인터내셔널(주)', '미디어브로스(주)', '스토리 너머,아이 엠',
#        '(주)영진크리에이티브,(유)조이앤컨텐츠그룹', '노가리필름,(주)인디플러그', '(주)26컴퍼니,윤스',
#        '(주)씨네로닷컴', '뎁스프로덕션', '드림로드', '펜타브리드', '주식회사 콘텐츠플레이', '(주)영화사 조은',
#        '이돌영화사', '목영이엔엠,(주)다자인소프트', '(주)고맙습니다 사랑합니다', '(주)아르떼',
#        '(주)전망좋은 영화사', '주식회사 씨엠닉스,어뮤즈', '전망 PRODUCTION', '(주)마부엔터테인먼트',
#        '(주)엠씨엠씨', '영화사 조선호랑이', '(주)코코믹스', '주식회사 마운틴픽쳐스,주식회사 블루필름웍스',
#        '(주)컨텐츠 빌리지', '(주)파노라마엔터테인먼트', '보리와 오디 영화사', '(주)로드픽쳐스', '㈜리필름',
#        '모비딕엔터테인먼트(주)', '테디베어필름', '(주)디에이치미디어', '(주)영화맞춤제작소 영화공장',
#        '(주)다날엔터테인먼트,THE 픽쳐스', '(주)인터오리진아이엔씨', '(주)휘엔터테인먼트',
#        '더 필름클래식 프로덕션', '이공희 필름,시네마 뉴원', '주식회사 마운틴픽쳐스,(주)액티버스엔터테인먼트',
#        '프로젝트 엠피', '썬택엔터테인먼트 주식회사', '전국예술영화관협회', '(주)제이디테크', '(주)투모션',
#        '(주)마이애미미디어', '(주)푸른별 엔터테인먼트', '(주)담화', '제이프러스미디어', '(주)플랜오십일',
#        '선셋 시네마', '(주)메이크아트', '핵존슨', '판타스틱룸미디어', '(주)코랄픽쳐스', '(주)한사리미디어',
#        '(주)가온콘텐츠', '스마일컨텐츠', '(주)엔트리미디어', '(주)레드언더미디어', '(주)씨맥스커뮤니케이션즈',
#        '라온컴퍼니', '(주)인포투스', '(주)그라운드미디어', '컨버전스티비', '(주)스토리제이', '(주)농담',
#        '(주)코빈커뮤니케이션즈', '오디씨네마', '주식회사 블루필름웍스,(주)무빙픽쳐스컴퍼니', '주식회사 제이씨엔터웍스',
#        'RGB', '유한회사 영화사 반딧불', '케이엘 픽쳐스', '프리포트', '씨엔티테크(주)', '주식회사 플릭스코',
#        '조박픽쳐스', '두리컴', '케이제이픽처스', '너바나 필름', '양전프로덕션', '(주)다날엔터테인먼트',
#        '(주)인터하우스', '(주)인터하우스,노바엔터테인먼트', '(주)데이드림서울', '(주)노이에스',
#        '(주)매니아22', '닷 팩토리', '(주)이모션픽처스,(주)제이에프엔터테인먼트', '(주)영화사가을',
#        '(주)포커스엔터테인먼트', '(주)추억을 파는 극장', '(주)씨맥스이앤씨', '굿픽처스', '99film',
#        '(주)픽쳐레스크', '더컨텐츠콤(주)', '올드웨일', '(주)네스팅', '(주)케이피에이기획', '콩미디어',
#        'YJ COMPANY', '에이원 미디어', '미래로 엔터테인먼트', '유로 프로덕션', '(주)에스와이미디어',
#        '조이앤키노', '주식회사 레드아이스', '㈜T-JOY,(주)미로비젼', "'탁주'조합", '제뉴어리이공 현프로',
#        '비에이치제이 시네마', '에이 라이프', '(주)무브먼트 픽쳐스', '마그넷 엔터테인먼터', '(주)대양미디어',
#        '영화사 유일무이', '한국문화예술위원회', '스턴트코리아', '(주)히스토리필름', '(주)디어프로덕션',
#        '(주)엔씨미디어', '(주)재원엔터테인먼트', '(주)콘텐츠랩자박', '월드 영화사', '록엔터테인먼트(주)',
#        '(주)시네마리퍼블릭', '라임필름', '유니콘미디어(주)', '씨네힐', '(주)엘케이픽쳐스',
#        '(주)티에스앤컴퍼니', '페어팍스인터내셔날(주)', '주식회사 이엔터', '디자인 콘텐츠', '씨네라인월드(주)',
#        '유한회사 올빼미하우스', '하드릴컴퍼니', '아이앤지픽쳐스', '바심미디어', '(주)뭉게구름', 'C2 미디어',
#        '나이스플레이(주)', '(주)노시스컴퍼니', '블리트필름', '레이크엔터테인먼트', '(주)아이아스플러스',
#        '(주)아펙스 엔터테인먼트,(주)키노아이디엠씨', '비에이치제이시네마', '(주)영진크리에이티브', 'BX 픽쳐스',
#        '아이브엔터테인먼트', '(주)플라이어', '(주)동아수출공사', '레지스탕스 필름,(주)파란프로덕션',
#        '(주)아이엠비씨', '노네임 필름', '㈜메가박스', '(주)테라맥스엔터테인먼트', '(주)루스아트',
#        '(주)아펙스 엔터테인먼트', '주식회사 미콘', '(주)제이엠씨미디어', '(주)제이앤씨미디어그룹,(유)조이앤시네마',
#        '(주)영화사 숲', '골든타이드픽처스(주),Yellow Pictures', '웅 픽쳐스', 'SK 브로드밴드',
#        '시네마테크 충무로', '(주)모인그룹', '미카사미디어', '(주)콘텐츠게이트', '(주)알이디아이스엔터',
#        '퓨쳐스', '(주)이엔엔터테인먼트', '(주)아피아스튜디오', '(주)빅콘미디어', '(주)트루에버', '뷰소프트',
#        '(주)아이브픽쳐스', '(주)조이컴퍼니', '라온아이(주)', '(주)오렌지옐로우하임', '(주)피에이치미디어',
#        '엔트리커뮤니케이션즈', '파파나', 'TCO(주)더콘텐츠온,(주)케이알씨지', 'P&미디어', '(주)뮤직엔닷컴',
#        '엠아이픽쳐스', '비스킷미디어', '펀펀한영화사', '(주)영화공간', '노다지엔터테인먼트', '(주)블루라벨픽쳐스',
#        '(주)예당씨앤에스', '세도나아이(주)', '(주)빅마운틴컬쳐스', '영화사마농주식회사', '영화사 산들바람',
#        '주식회사 락희상회', '(주)온비즈넷', 'S&S', '(유)헤이데이웍스', '(주)달빛공장', '(주)해머픽쳐스',
#        '(주)룬컴퍼니', '컴퍼니 엘론(주)', '(주)오예스', '하드릴', '레인주니어 픽쳐스'], dtype=object)

# %%
# 다수의 배급사 데이터 변경
for idx, row in movie.iterrows():
    if ',' in row['배급사']:
        distributor = row['배급사'].split(',')
        # 양 끝 공백 제거 후 변경
        movie['배급사'][idx] = distributor[0].strip()

# %% [markdown]
# - 대표 배급사 선정으로 300개가 줄어 606개가 되었다.
# - 확인한 결과 디즈니, 소니픽쳐스, CGV, 롯데, 메가박스 5개의 경우 반복되는 경우가 있다.
#   - 이러한 경우는 동일한 것으로 보고 ['디즈니', '소니픽쳐스', 'CGV', '롯데', '메가박스']로 변경해준다.

# %%
print(len(movie['배급사'].unique()))
# Out:
# 606

# %%
movie['배급사'].unique()
# Out:
# array(['(주)씨제이이엔엠', '롯데쇼핑㈜롯데엔터테인먼트', '월트디즈니컴퍼니코리아 유한책임회사', '(주)쇼박스',
#        '(주)넥스트엔터테인먼트월드(NEW)', '롯데컬처웍스(주)롯데엔터테인먼트',
#        '소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)', '워너브러더스 코리아(주)', '월트디즈니컴퍼니코리아(주)',
#        '소니픽쳐스엔터테인먼트코리아주식회사극장배급지점', '이십세기폭스코리아(주)', '메가박스중앙(주)플러스엠',
#        '유니버설픽쳐스인터내셔널 코리아(유)', '한국소니픽쳐스릴리징브에나비스타영화㈜', 'CGV아트하우스',
#        '판씨네마(주)', '(주)와우픽쳐스', '(주)에이스메이커무비웍스', '(주)스튜디오디에이치엘', '아이러브시네마',
#        '(주)인벤트스톤', '필라멘트픽쳐스', '오퍼스픽쳐스(유)', '에스케이플래닛(주)', '씨네그루(주)다우기술',
#        '(주)메리크리스마스', 'CJ ENM', '(주)제이앤씨미디어그룹', '씨너스엔터테인먼트(주)',
#        '(주)영화사 그램', '주식회사 해리슨앤컴퍼니', '워터홀컴퍼니(주)', '(주)키다리이엔티', '(주)디스테이션',
#        '(주)시너지하우스 (시너지)', '(주)에스비에스콘텐츠허브', '(주)누리픽쳐스', '글뫼 주식회사',
#        '(주)시네마서비스', '(주)스마일이엔티', '(주)올스타엔터테인먼트', '(주)화앤담이엔티', '(주)리틀빅픽쳐스',
#        '(주)피터팬픽쳐스', '(주)미디어데이', '(주)싸이더스', '유나이티드픽처스(주)', '주식회사 우리네트웍스',
#        '(주)나이너스엔터테인먼트', '(주)이수C&E', '(주)엣나인필름', 'TCO(주)더콘텐츠온', '영화사올(주)',
#        '(주)콘텐츠 난다긴다', '(주)마인스 엔터테인먼트', '오드', '주식회사 마운틴픽쳐스', '(주)팝엔터테인먼트',
#        '주식회사 더쿱', '씨제이 씨지브이(CJ CGV)(주)', 'CGV ICECON', '(주)프레인글로벌',
#        '(주)삼백상회', '(주)박수엔터테인먼트', '타임스토리그룹(주)', '(주)팝파트너스', '(재)CBS',
#        '예지림엔터테인먼트', '(주)영화사 빅', '(주)홈초이스', '㈜코리아스크린', '(주)그노스',
#        '(주)이놀미디어', '(주)까멜리아이엔티', '(주)모멘텀엔터테인먼트', '(주)키위미디어그룹', '(주)티캐스트',
#        '(주)셀트리온엔터테인먼트', '(주)대명문화공장', '에스케이텔레콤(주)', '에이원엔터테인먼트',
#        '그린나래미디어(주)', '(주)영화사 진진', '찬란', '와이드 릴리즈(주)', '(주)아이코닉스',
#        '(주)콘텐츠판다', '커넥트픽쳐스(주)', '(주)티캐스트콘텐츠허브',
#        'KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', '팝엔터테인먼트', '동우에이앤이(주)', '(주)삼지애니메이션',
#        '(주)지어소프트', '블루미지', '(주)트리플픽쳐스', '(주)영화사오원', '씨제이포디플렉스 주식회사',
#        '(주)드림팩트엔터테인먼트', '(주)무빙픽쳐스컴퍼니', '(주)케이티알파', '파이오니아21',
#        '(주)더블앤조이픽쳐스', '(주)크리픽쳐스', '(주)애니플러스', '기타', '(주)라이크콘텐츠',
#        '(주)영화제작전원사', '(유)조이앤시네마', '(주)포켓몬코리아', '(주)시네마달', '(주)영화특별시에스엠씨',
#        '(주)와이즈베이', '이언픽쳐스', '(주)스톰픽쳐스코리아', '(주)브리즈픽처스', '㈜T-JOY',
#        '대원미디어(주)', '힘컨텐츠(주)', '(주)퍼스트런', 'THE 픽쳐스', '㈜영화사 백두대간',
#        '(주)미디어캐슬', '(주)다자인소프트', '주식회사 온 피크', '㈜씨에이엔', '(주)메인타이틀픽쳐스',
#        '주식회사 디에스이이디', '(주)엠제이픽쳐스', '(주)아이엠비씨', '(주)마노엔터테인먼트', '(주)인디플러그',
#        '(주)미로비젼', '(주)스튜디오 보난자', '어뮤즈', '골든타이드픽처스(주)', '(주)두타연', '㈜인디스토리',
#        '(주)에스와이코마드', '이달투', '(주)에스피엠', '(주)디오시네마', '브릿지웍스 엔터테인먼트(주)',
#        '(주)머스트씨무비릴리징컴퍼니', '(주)씨네포트', '(주)빅웨이브시네마', '플레이리스트(주)', '아이 엠',
#        '㈜케이디미디어', '제인앤유', '(주)팬엔터테인먼트', '(주)드림웨스트픽쳐스', '롯데쇼핑㈜롯데시네마',
#        '(주)버킷스튜디오', '(주)좋은 하늘', 'KBS 미디어', '오키넷', '주식회사 씨네룩스',
#        '영화사 마농(주)', '(주)블룸즈베리파트너스', '<나쁜 나라> 배급위원회', '(주)화인픽쳐스',
#        '주식회사 왓챠', '(주)대교 미디어콘텐츠사업본부', '(주)아우라픽처스', '(주)영화사조아',
#        '스튜디오 프로그레시브 인큐베이터', '(주)미디어로그', '주식회사 풍경소리', '주식회사 단유필름',
#        '(주)명필름', '(주)영화사 안다미로', '(주)영화사 조제', '(주)머스트씨무비', '데이지엔터테인먼트',
#        '(주)메타플레이', '영화사 풀', '주식회사 슈아픽처스', '알토미디어(주)', '시네마 뉴원',
#        '(주)씨에이씨엔터테인먼트', '스마트스터디(주)', '(주)앤드플러스미디어웍스', '스튜디오느림보',
#        '(주)소나무픽쳐스', '(주)중헌홀딩스', '(주)블룸즈베리리소시스리미티드', '(주)알앤오엔터테인먼트',
#        '프리비젼엔터테인먼트', '(주)디지컴코리아엠앤엠', '주식회사 블루필름웍스', '(주)더 피플',
#        '(주)뮤제엔터테인먼트', '뉴원시네마', '씨네21아이(주)', '(주)에이원엔터테인먼트', '스크린조이',
#        '(주)비싸이드 픽쳐스', '(주)김기덕 필름', '(주)한마음프로덕션', 'M&M 인터내셔널', '(주)영화사샘',
#        '(주)키노아이디엠씨', '(유)조이앤컨텐츠그룹', '(주)필마픽쳐스', '주식회사 쇼미미디어앤트레이딩',
#        '(주)미로스페이스', '메가박스중앙(주)', '(주)패뷸러스', '(주)바른손이앤에이', '에스디시코리아 주식회사',
#        '케이비에스미디어(주)', '(주)영화사선', '퍼즐엔터테인먼트', '(주) 인스터 글로벌', '(주)스크린와이즈',
#        '(주)수키픽쳐스', '노바엔터테인먼트', '(주)판다미디어', '(주)미루픽처스', '하준사', '익스트림 필름',
#        '(주)서태지컴퍼니', '시네마달', '(주)케이알씨지', '영화사 민들레', '(주)컴퍼니엘',
#        '(주)에이썸엔터테인먼트', '(주)영화사폴', '(주)률필름', '(주)유비네트워크', '미디어소프트',
#        '(주)스크린다', '얼리버드', '(주)엔케이컨텐츠', '(주)레몬트리픽쳐스', '딥 포커스', '세븐바이투픽쳐스',
#        '무브먼트', '삼라 주식회사', '(주) 루스이소니도스', '주식회사 드림크리에이션', '아이제이미디어(주)',
#        '(주)도키엔터테인먼트', '(주)유로커뮤니케이션', '애니메이션 배급', '(재)전주국제영화제조직위원회',
#        'C 무비', '(주)일레븐엔터테인먼트', '(주)로드하우스', '(주)에이블엔터테인먼트', '(주)레인메이커필름',
#        '(주)케빈앤컴퍼니', '미디어 컨텐츠 스토어', '씨드', '미라클필름', '(주)올댓시네마 플러스',
#        '영화사 마그나', '(주)라온컴퍼니플러스', '상남영화제작소', '홀리가든', '52DAYS FILM',
#        '(유)영화사 화수분', '(주)쓰리캣프로덕션', '(주)오렌지옐로우하임', '다솔기획', '데이브인터랙티브',
#        '위드 라이언 픽쳐스', '(주)영화사메이플러스', '(주)따미픽쳐스', '서울독립영화제', '퓨어웨이픽쳐스',
#        '(주)트리필름', '필름메신저', '(주)민치앤필름', '호우주의보', '(주)노바이앤티', '윤스',
#        '(사)필레마', '(주)씨네마드마농', '주식회사 세미콜론스튜디오', '(주)비프로', '(주)레인보우팩토리',
#        '영화사 무명', '이미지팩토리', '(주)갑종무비필름', '투썸업픽쳐스', '강 컨텐츠', '롤러코스터',
#        '필름에이픽쳐스', '파인스토리', '필름다빈', '(주)액티버스엔터테인먼트', '영화사 삼순', '문화선교연구원',
#        '(주)월드시네마', '(주)맑은시네마', '(주)디앤아이컴퍼니', '스토리 너머', '다큐스토리', '(주)스넵쏘울',
#        '(주)시네마엔터', '(주)에픽캔', '(주)랠리버튼', '(주)미디어이야기', '고구마콘텐츠허브(주)',
#        '(주)베드픽쳐스', '영희야 놀자', '㈜크래커픽쳐스', '영화배급협동조합 씨네소파', '(주)엠레콘',
#        '(주)토러스엔터테인먼트', '씨네굿', '(주)문와쳐', '주식회사 골든럭', '팔레드시네마(주)', '어썸피플',
#        '(주)로카', 'ZONE Film', '레드무비', '(주)자우엔터테인먼트', '(주)미디어 마그나', '독포레스트',
#        '밀크픽처스', 'CL2D Film', '(주)스토리제이', '명필름랩', '반달', '라인트리엔터테인먼트',
#        '주식회사 노버스엔터테인먼트', '아방가르드 필름', '스마일픽쳐스', '퍼즐컷', '시네마서울', '엠투',
#        '(주)콘텐츠윙', '(주)아이디어랩', '제이리미디어', '주식회사 키노엔터테인먼트', '(재)영화의전당',
#        '애니박스 엔터테인먼트', '매치컷(주)', '모두를위한극장 공정영화협동조합', '해피송', '(주)나우콘텐츠',
#        '페퍼민트픽쳐스', '(주)차룡영화사', '(주)티앤엘엔터테인먼트', '전국예술영화관협회', '씨네쿼넌 픽쳐스',
#        '(주)원더스컴퍼니', '(주)에이씨피컴퍼니', '야간비행', '(주)유어스토리블루', '길스토리',
#        '주식회사 루믹스미디어', '㈜스토리셋', '(주)스튜디오후크', '포커스 온', '㈜싸이더스픽쳐스', '일미디어',
#        '크리에이티브컴즈(주)', '제나두엔터테인먼트', '플랫폼C', '즐감', '프로젝트 엔터테인먼트',
#        '태창엔터테인먼트(주)', '주식회사 씨엠닉스', '(주)투한미디어', '(주)더그레이트컴퍼니', '쟈비스미디어',
#        '성길시네마', '영화사 보라', '디에이치 컴퍼니', '(주)제이에이와이이엔터테인먼트', '에이라인',
#        '(주)영화사히트', '마법사필름', '(주)얼리버드픽쳐스', '(주)갤럭시컴퍼니', '(주)두엔터테인먼트',
#        '(주)로이테미디어', '(주)웃기씨네', '(주)우성엔터테인먼트', '더사람픽쳐스', '달밤체조(주)',
#        '(주)투윈미디어', '주식회사 비엠미디어', '디마엔터테인먼트', '(주)마고필름', '이닥픽쳐스',
#        '(사)독립영화전용관 확대를 위한 시민모임', '(주)KW비젼', '(주)노리픽쳐스', '(주)이모션픽처스',
#        '영화사 인연', '(주)케이앤엔터테인먼트', '예술의전당', '조이월드앤다이버시티', '레인메이커필름',
#        '(주)아바엔터테인먼트', '(주)26컴퍼니', '(주)제이브로', '(주)선익필름', '(주)블루브릭',
#        '(주)영화사 사계절', '(주)인피니티엔터테인먼트', '(주)백그림', '이상우필름', '(유)쏘아필름',
#        '봄바람영화사', '(주)에이앤비픽쳐스', '씨네마캣 픽쳐스', '(주)H.F.G엔터테인먼트',
#        '크리스리픽쳐스인터내셔널(주)', '미디어브로스(주)', '(주)영진크리에이티브', '노가리필름', '(주)씨네로닷컴',
#        '뎁스프로덕션', '드림로드', '펜타브리드', '주식회사 콘텐츠플레이', '(주)영화사 조은', '이돌영화사',
#        '목영이엔엠', '(주)고맙습니다 사랑합니다', '(주)아르떼', '(주)전망좋은 영화사',
#        '전망 PRODUCTION', '(주)마부엔터테인먼트', '(주)엠씨엠씨', '영화사 조선호랑이', '(주)코코믹스',
#        '(주)컨텐츠 빌리지', '(주)파노라마엔터테인먼트', '보리와 오디 영화사', '(주)로드픽쳐스', '㈜리필름',
#        '모비딕엔터테인먼트(주)', '테디베어필름', '(주)디에이치미디어', '(주)영화맞춤제작소 영화공장',
#        '(주)다날엔터테인먼트', '(주)인터오리진아이엔씨', '(주)휘엔터테인먼트', '더 필름클래식 프로덕션',
#        '이공희 필름', '프로젝트 엠피', '썬택엔터테인먼트 주식회사', '(주)제이디테크', '(주)투모션',
#        '(주)마이애미미디어', '(주)푸른별 엔터테인먼트', '(주)담화', '제이프러스미디어', '(주)플랜오십일',
#        '선셋 시네마', '(주)메이크아트', '핵존슨', '판타스틱룸미디어', '(주)코랄픽쳐스', '(주)한사리미디어',
#        '(주)가온콘텐츠', '스마일컨텐츠', '(주)엔트리미디어', '(주)레드언더미디어', '(주)씨맥스커뮤니케이션즈',
#        '라온컴퍼니', '(주)인포투스', '(주)그라운드미디어', '컨버전스티비', '(주)농담',
#        '(주)코빈커뮤니케이션즈', '오디씨네마', '주식회사 제이씨엔터웍스', 'RGB', '유한회사 영화사 반딧불',
#        '케이엘 픽쳐스', '프리포트', '씨엔티테크(주)', '주식회사 플릭스코', '조박픽쳐스', '두리컴',
#        '케이제이픽처스', '너바나 필름', '양전프로덕션', '(주)인터하우스', '(주)데이드림서울', '(주)노이에스',
#        '(주)매니아22', '닷 팩토리', '(주)영화사가을', '(주)포커스엔터테인먼트', '(주)추억을 파는 극장',
#        '(주)씨맥스이앤씨', '굿픽처스', '99film', '(주)픽쳐레스크', '더컨텐츠콤(주)', '올드웨일',
#        '(주)네스팅', '(주)케이피에이기획', '콩미디어', 'YJ COMPANY', '에이원 미디어',
#        '미래로 엔터테인먼트', '유로 프로덕션', '(주)에스와이미디어', '조이앤키노', '주식회사 레드아이스',
#        "'탁주'조합", '제뉴어리이공 현프로', '비에이치제이 시네마', '에이 라이프', '(주)무브먼트 픽쳐스',
#        '마그넷 엔터테인먼터', '(주)대양미디어', '영화사 유일무이', '한국문화예술위원회', '스턴트코리아',
#        '(주)히스토리필름', '(주)디어프로덕션', '(주)엔씨미디어', '(주)재원엔터테인먼트', '(주)콘텐츠랩자박',
#        '월드 영화사', '록엔터테인먼트(주)', '(주)시네마리퍼블릭', '라임필름', '유니콘미디어(주)', '씨네힐',
#        '(주)엘케이픽쳐스', '(주)티에스앤컴퍼니', '페어팍스인터내셔날(주)', '주식회사 이엔터', '디자인 콘텐츠',
#        '씨네라인월드(주)', '유한회사 올빼미하우스', '하드릴컴퍼니', '아이앤지픽쳐스', '바심미디어',
#        '(주)뭉게구름', 'C2 미디어', '나이스플레이(주)', '(주)노시스컴퍼니', '블리트필름',
#        '레이크엔터테인먼트', '(주)아이아스플러스', '(주)아펙스 엔터테인먼트', '비에이치제이시네마', 'BX 픽쳐스',
#        '아이브엔터테인먼트', '(주)플라이어', '(주)동아수출공사', '레지스탕스 필름', '노네임 필름', '㈜메가박스',
#        '(주)테라맥스엔터테인먼트', '(주)루스아트', '주식회사 미콘', '(주)제이엠씨미디어', '(주)영화사 숲',
#        '웅 픽쳐스', 'SK 브로드밴드', '시네마테크 충무로', '(주)모인그룹', '미카사미디어', '(주)콘텐츠게이트',
#        '(주)알이디아이스엔터', '퓨쳐스', '(주)이엔엔터테인먼트', '(주)아피아스튜디오', '(주)빅콘미디어',
#        '(주)트루에버', '뷰소프트', '(주)아이브픽쳐스', '(주)조이컴퍼니', '라온아이(주)',
#        '(주)피에이치미디어', '엔트리커뮤니케이션즈', '파파나', 'P&미디어', '(주)뮤직엔닷컴', '엠아이픽쳐스',
#        '비스킷미디어', '펀펀한영화사', '(주)영화공간', '노다지엔터테인먼트', '(주)블루라벨픽쳐스',
#        '(주)예당씨앤에스', '세도나아이(주)', '(주)빅마운틴컬쳐스', '영화사마농주식회사', '영화사 산들바람',
#        '주식회사 락희상회', '(주)온비즈넷', 'S&S', '(유)헤이데이웍스', '(주)달빛공장', '(주)해머픽쳐스',
#        '(주)룬컴퍼니', '컴퍼니 엘론(주)', '(주)오예스', '하드릴', '레인주니어 픽쳐스'], dtype=object)

# %%
# 중복 배급사 변경
distributor = ['디즈니', '소니픽쳐스', 'CGV', '롯데', '메가박스']
for idx, row in movie.iterrows():
    for d in distributor:
        if d in row['배급사']:
            movie['배급사'][idx] = d

# %% [markdown]
# - 중복 제거 후 최종적으로 597개의 유형이 남았다.

# %%
len(movie['배급사'].unique()), movie['배급사'].unique()
# Out:
# (597,
#  array(['(주)씨제이이엔엠', '롯데', '디즈니', '(주)쇼박스', '(주)넥스트엔터테인먼트월드(NEW)', '소니픽쳐스',
#         '워너브러더스 코리아(주)', '이십세기폭스코리아(주)', '메가박스', '유니버설픽쳐스인터내셔널 코리아(유)',
#         'CGV', '판씨네마(주)', '(주)와우픽쳐스', '(주)에이스메이커무비웍스', '(주)스튜디오디에이치엘',
#         '아이러브시네마', '(주)인벤트스톤', '필라멘트픽쳐스', '오퍼스픽쳐스(유)', '에스케이플래닛(주)',
#         '씨네그루(주)다우기술', '(주)메리크리스마스', 'CJ ENM', '(주)제이앤씨미디어그룹',
#         '씨너스엔터테인먼트(주)', '(주)영화사 그램', '주식회사 해리슨앤컴퍼니', '워터홀컴퍼니(주)',
#         '(주)키다리이엔티', '(주)디스테이션', '(주)시너지하우스 (시너지)', '(주)에스비에스콘텐츠허브',
#         '(주)누리픽쳐스', '글뫼 주식회사', '(주)시네마서비스', '(주)스마일이엔티', '(주)올스타엔터테인먼트',
#         '(주)화앤담이엔티', '(주)리틀빅픽쳐스', '(주)피터팬픽쳐스', '(주)미디어데이', '(주)싸이더스',
#         '유나이티드픽처스(주)', '주식회사 우리네트웍스', '(주)나이너스엔터테인먼트', '(주)이수C&E',
#         '(주)엣나인필름', 'TCO(주)더콘텐츠온', '영화사올(주)', '(주)콘텐츠 난다긴다',
#         '(주)마인스 엔터테인먼트', '오드', '주식회사 마운틴픽쳐스', '(주)팝엔터테인먼트', '주식회사 더쿱',
#         '(주)프레인글로벌', '(주)삼백상회', '(주)박수엔터테인먼트', '타임스토리그룹(주)', '(주)팝파트너스',
#         '(재)CBS', '예지림엔터테인먼트', '(주)영화사 빅', '(주)홈초이스', '㈜코리아스크린', '(주)그노스',
#         '(주)이놀미디어', '(주)까멜리아이엔티', '(주)모멘텀엔터테인먼트', '(주)키위미디어그룹', '(주)티캐스트',
#         '(주)셀트리온엔터테인먼트', '(주)대명문화공장', '에스케이텔레콤(주)', '에이원엔터테인먼트',
#         '그린나래미디어(주)', '(주)영화사 진진', '찬란', '와이드 릴리즈(주)', '(주)아이코닉스',
#         '(주)콘텐츠판다', '커넥트픽쳐스(주)', '(주)티캐스트콘텐츠허브',
#         'KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', '팝엔터테인먼트', '동우에이앤이(주)', '(주)삼지애니메이션',
#         '(주)지어소프트', '블루미지', '(주)트리플픽쳐스', '(주)영화사오원', '씨제이포디플렉스 주식회사',
#         '(주)드림팩트엔터테인먼트', '(주)무빙픽쳐스컴퍼니', '(주)케이티알파', '파이오니아21',
#         '(주)더블앤조이픽쳐스', '(주)크리픽쳐스', '(주)애니플러스', '기타', '(주)라이크콘텐츠',
#         '(주)영화제작전원사', '(유)조이앤시네마', '(주)포켓몬코리아', '(주)시네마달', '(주)영화특별시에스엠씨',
#         '(주)와이즈베이', '이언픽쳐스', '(주)스톰픽쳐스코리아', '(주)브리즈픽처스', '㈜T-JOY',
#         '대원미디어(주)', '힘컨텐츠(주)', '(주)퍼스트런', 'THE 픽쳐스', '㈜영화사 백두대간',
#         '(주)미디어캐슬', '(주)다자인소프트', '주식회사 온 피크', '㈜씨에이엔', '(주)메인타이틀픽쳐스',
#         '주식회사 디에스이이디', '(주)엠제이픽쳐스', '(주)아이엠비씨', '(주)마노엔터테인먼트', '(주)인디플러그',
#         '(주)미로비젼', '(주)스튜디오 보난자', '어뮤즈', '골든타이드픽처스(주)', '(주)두타연', '㈜인디스토리',
#         '(주)에스와이코마드', '이달투', '(주)에스피엠', '(주)디오시네마', '브릿지웍스 엔터테인먼트(주)',
#         '(주)머스트씨무비릴리징컴퍼니', '(주)씨네포트', '(주)빅웨이브시네마', '플레이리스트(주)', '아이 엠',
#         '㈜케이디미디어', '제인앤유', '(주)팬엔터테인먼트', '(주)드림웨스트픽쳐스', '(주)버킷스튜디오',
#         '(주)좋은 하늘', 'KBS 미디어', '오키넷', '주식회사 씨네룩스', '영화사 마농(주)',
#         '(주)블룸즈베리파트너스', '<나쁜 나라> 배급위원회', '(주)화인픽쳐스', '주식회사 왓챠',
#         '(주)대교 미디어콘텐츠사업본부', '(주)아우라픽처스', '(주)영화사조아', '스튜디오 프로그레시브 인큐베이터',
#         '(주)미디어로그', '주식회사 풍경소리', '주식회사 단유필름', '(주)명필름', '(주)영화사 안다미로',
#         '(주)영화사 조제', '(주)머스트씨무비', '데이지엔터테인먼트', '(주)메타플레이', '영화사 풀',
#         '주식회사 슈아픽처스', '알토미디어(주)', '시네마 뉴원', '(주)씨에이씨엔터테인먼트', '스마트스터디(주)',
#         '(주)앤드플러스미디어웍스', '스튜디오느림보', '(주)소나무픽쳐스', '(주)중헌홀딩스',
#         '(주)블룸즈베리리소시스리미티드', '(주)알앤오엔터테인먼트', '프리비젼엔터테인먼트', '(주)디지컴코리아엠앤엠',
#         '주식회사 블루필름웍스', '(주)더 피플', '(주)뮤제엔터테인먼트', '뉴원시네마', '씨네21아이(주)',
#         '(주)에이원엔터테인먼트', '스크린조이', '(주)비싸이드 픽쳐스', '(주)김기덕 필름', '(주)한마음프로덕션',
#         'M&M 인터내셔널', '(주)영화사샘', '(주)키노아이디엠씨', '(유)조이앤컨텐츠그룹', '(주)필마픽쳐스',
#         '주식회사 쇼미미디어앤트레이딩', '(주)미로스페이스', '(주)패뷸러스', '(주)바른손이앤에이',
#         '에스디시코리아 주식회사', '케이비에스미디어(주)', '(주)영화사선', '퍼즐엔터테인먼트',
#         '(주) 인스터 글로벌', '(주)스크린와이즈', '(주)수키픽쳐스', '노바엔터테인먼트', '(주)판다미디어',
#         '(주)미루픽처스', '하준사', '익스트림 필름', '(주)서태지컴퍼니', '시네마달', '(주)케이알씨지',
#         '영화사 민들레', '(주)컴퍼니엘', '(주)에이썸엔터테인먼트', '(주)영화사폴', '(주)률필름',
#         '(주)유비네트워크', '미디어소프트', '(주)스크린다', '얼리버드', '(주)엔케이컨텐츠',
#         '(주)레몬트리픽쳐스', '딥 포커스', '세븐바이투픽쳐스', '무브먼트', '삼라 주식회사',
#         '(주) 루스이소니도스', '주식회사 드림크리에이션', '아이제이미디어(주)', '(주)도키엔터테인먼트',
#         '(주)유로커뮤니케이션', '애니메이션 배급', '(재)전주국제영화제조직위원회', 'C 무비',
#         '(주)일레븐엔터테인먼트', '(주)로드하우스', '(주)에이블엔터테인먼트', '(주)레인메이커필름',
#         '(주)케빈앤컴퍼니', '미디어 컨텐츠 스토어', '씨드', '미라클필름', '(주)올댓시네마 플러스',
#         '영화사 마그나', '(주)라온컴퍼니플러스', '상남영화제작소', '홀리가든', '52DAYS FILM',
#         '(유)영화사 화수분', '(주)쓰리캣프로덕션', '(주)오렌지옐로우하임', '다솔기획', '데이브인터랙티브',
#         '위드 라이언 픽쳐스', '(주)영화사메이플러스', '(주)따미픽쳐스', '서울독립영화제', '퓨어웨이픽쳐스',
#         '(주)트리필름', '필름메신저', '(주)민치앤필름', '호우주의보', '(주)노바이앤티', '윤스',
#         '(사)필레마', '(주)씨네마드마농', '주식회사 세미콜론스튜디오', '(주)비프로', '(주)레인보우팩토리',
#         '영화사 무명', '이미지팩토리', '(주)갑종무비필름', '투썸업픽쳐스', '강 컨텐츠', '롤러코스터',
#         '필름에이픽쳐스', '파인스토리', '필름다빈', '(주)액티버스엔터테인먼트', '영화사 삼순', '문화선교연구원',
#         '(주)월드시네마', '(주)맑은시네마', '(주)디앤아이컴퍼니', '스토리 너머', '다큐스토리', '(주)스넵쏘울',
#         '(주)시네마엔터', '(주)에픽캔', '(주)랠리버튼', '(주)미디어이야기', '고구마콘텐츠허브(주)',
#         '(주)베드픽쳐스', '영희야 놀자', '㈜크래커픽쳐스', '영화배급협동조합 씨네소파', '(주)엠레콘',
#         '(주)토러스엔터테인먼트', '씨네굿', '(주)문와쳐', '주식회사 골든럭', '팔레드시네마(주)', '어썸피플',
#         '(주)로카', 'ZONE Film', '레드무비', '(주)자우엔터테인먼트', '(주)미디어 마그나', '독포레스트',
#         '밀크픽처스', 'CL2D Film', '(주)스토리제이', '명필름랩', '반달', '라인트리엔터테인먼트',
#         '주식회사 노버스엔터테인먼트', '아방가르드 필름', '스마일픽쳐스', '퍼즐컷', '시네마서울', '엠투',
#         '(주)콘텐츠윙', '(주)아이디어랩', '제이리미디어', '주식회사 키노엔터테인먼트', '(재)영화의전당',
#         '애니박스 엔터테인먼트', '매치컷(주)', '모두를위한극장 공정영화협동조합', '해피송', '(주)나우콘텐츠',
#         '페퍼민트픽쳐스', '(주)차룡영화사', '(주)티앤엘엔터테인먼트', '전국예술영화관협회', '씨네쿼넌 픽쳐스',
#         '(주)원더스컴퍼니', '(주)에이씨피컴퍼니', '야간비행', '(주)유어스토리블루', '길스토리',
#         '주식회사 루믹스미디어', '㈜스토리셋', '(주)스튜디오후크', '포커스 온', '㈜싸이더스픽쳐스', '일미디어',
#         '크리에이티브컴즈(주)', '제나두엔터테인먼트', '플랫폼C', '즐감', '프로젝트 엔터테인먼트',
#         '태창엔터테인먼트(주)', '주식회사 씨엠닉스', '(주)투한미디어', '(주)더그레이트컴퍼니', '쟈비스미디어',
#         '성길시네마', '영화사 보라', '디에이치 컴퍼니', '(주)제이에이와이이엔터테인먼트', '에이라인',
#         '(주)영화사히트', '마법사필름', '(주)얼리버드픽쳐스', '(주)갤럭시컴퍼니', '(주)두엔터테인먼트',
#         '(주)로이테미디어', '(주)웃기씨네', '(주)우성엔터테인먼트', '더사람픽쳐스', '달밤체조(주)',
#         '(주)투윈미디어', '주식회사 비엠미디어', '디마엔터테인먼트', '(주)마고필름', '이닥픽쳐스',
#         '(사)독립영화전용관 확대를 위한 시민모임', '(주)KW비젼', '(주)노리픽쳐스', '(주)이모션픽처스',
#         '영화사 인연', '(주)케이앤엔터테인먼트', '예술의전당', '조이월드앤다이버시티', '레인메이커필름',
#         '(주)아바엔터테인먼트', '(주)26컴퍼니', '(주)제이브로', '(주)선익필름', '(주)블루브릭',
#         '(주)영화사 사계절', '(주)인피니티엔터테인먼트', '(주)백그림', '이상우필름', '(유)쏘아필름',
#         '봄바람영화사', '(주)에이앤비픽쳐스', '씨네마캣 픽쳐스', '(주)H.F.G엔터테인먼트',
#         '크리스리픽쳐스인터내셔널(주)', '미디어브로스(주)', '(주)영진크리에이티브', '노가리필름', '(주)씨네로닷컴',
#         '뎁스프로덕션', '드림로드', '펜타브리드', '주식회사 콘텐츠플레이', '(주)영화사 조은', '이돌영화사',
#         '목영이엔엠', '(주)고맙습니다 사랑합니다', '(주)아르떼', '(주)전망좋은 영화사',
#         '전망 PRODUCTION', '(주)마부엔터테인먼트', '(주)엠씨엠씨', '영화사 조선호랑이', '(주)코코믹스',
#         '(주)컨텐츠 빌리지', '(주)파노라마엔터테인먼트', '보리와 오디 영화사', '(주)로드픽쳐스', '㈜리필름',
#         '모비딕엔터테인먼트(주)', '테디베어필름', '(주)디에이치미디어', '(주)영화맞춤제작소 영화공장',
#         '(주)다날엔터테인먼트', '(주)인터오리진아이엔씨', '(주)휘엔터테인먼트', '더 필름클래식 프로덕션',
#         '이공희 필름', '프로젝트 엠피', '썬택엔터테인먼트 주식회사', '(주)제이디테크', '(주)투모션',
#         '(주)마이애미미디어', '(주)푸른별 엔터테인먼트', '(주)담화', '제이프러스미디어', '(주)플랜오십일',
#         '선셋 시네마', '(주)메이크아트', '핵존슨', '판타스틱룸미디어', '(주)코랄픽쳐스', '(주)한사리미디어',
#         '(주)가온콘텐츠', '스마일컨텐츠', '(주)엔트리미디어', '(주)레드언더미디어', '(주)씨맥스커뮤니케이션즈',
#         '라온컴퍼니', '(주)인포투스', '(주)그라운드미디어', '컨버전스티비', '(주)농담',
#         '(주)코빈커뮤니케이션즈', '오디씨네마', '주식회사 제이씨엔터웍스', 'RGB', '유한회사 영화사 반딧불',
#         '케이엘 픽쳐스', '프리포트', '씨엔티테크(주)', '주식회사 플릭스코', '조박픽쳐스', '두리컴',
#         '케이제이픽처스', '너바나 필름', '양전프로덕션', '(주)인터하우스', '(주)데이드림서울', '(주)노이에스',
#         '(주)매니아22', '닷 팩토리', '(주)영화사가을', '(주)포커스엔터테인먼트', '(주)추억을 파는 극장',
#         '(주)씨맥스이앤씨', '굿픽처스', '99film', '(주)픽쳐레스크', '더컨텐츠콤(주)', '올드웨일',
#         '(주)네스팅', '(주)케이피에이기획', '콩미디어', 'YJ COMPANY', '에이원 미디어',
#         '미래로 엔터테인먼트', '유로 프로덕션', '(주)에스와이미디어', '조이앤키노', '주식회사 레드아이스',
#         "'탁주'조합", '제뉴어리이공 현프로', '비에이치제이 시네마', '에이 라이프', '(주)무브먼트 픽쳐스',
#         '마그넷 엔터테인먼터', '(주)대양미디어', '영화사 유일무이', '한국문화예술위원회', '스턴트코리아',
#         '(주)히스토리필름', '(주)디어프로덕션', '(주)엔씨미디어', '(주)재원엔터테인먼트', '(주)콘텐츠랩자박',
#         '월드 영화사', '록엔터테인먼트(주)', '(주)시네마리퍼블릭', '라임필름', '유니콘미디어(주)', '씨네힐',
#         '(주)엘케이픽쳐스', '(주)티에스앤컴퍼니', '페어팍스인터내셔날(주)', '주식회사 이엔터', '디자인 콘텐츠',
#         '씨네라인월드(주)', '유한회사 올빼미하우스', '하드릴컴퍼니', '아이앤지픽쳐스', '바심미디어',
#         '(주)뭉게구름', 'C2 미디어', '나이스플레이(주)', '(주)노시스컴퍼니', '블리트필름',
#         '레이크엔터테인먼트', '(주)아이아스플러스', '(주)아펙스 엔터테인먼트', '비에이치제이시네마', 'BX 픽쳐스',
#         '아이브엔터테인먼트', '(주)플라이어', '(주)동아수출공사', '레지스탕스 필름', '노네임 필름',
#         '(주)테라맥스엔터테인먼트', '(주)루스아트', '주식회사 미콘', '(주)제이엠씨미디어', '(주)영화사 숲',
#         '웅 픽쳐스', 'SK 브로드밴드', '시네마테크 충무로', '(주)모인그룹', '미카사미디어', '(주)콘텐츠게이트',
#         '(주)알이디아이스엔터', '퓨쳐스', '(주)이엔엔터테인먼트', '(주)아피아스튜디오', '(주)빅콘미디어',
#         '(주)트루에버', '뷰소프트', '(주)아이브픽쳐스', '(주)조이컴퍼니', '라온아이(주)',
#         '(주)피에이치미디어', '엔트리커뮤니케이션즈', '파파나', 'P&미디어', '(주)뮤직엔닷컴', '엠아이픽쳐스',
#         '비스킷미디어', '펀펀한영화사', '(주)영화공간', '노다지엔터테인먼트', '(주)블루라벨픽쳐스',
#         '(주)예당씨앤에스', '세도나아이(주)', '(주)빅마운틴컬쳐스', '영화사마농주식회사', '영화사 산들바람',
#         '주식회사 락희상회', '(주)온비즈넷', 'S&S', '(유)헤이데이웍스', '(주)달빛공장', '(주)해머픽쳐스',
#         '(주)룬컴퍼니', '컴퍼니 엘론(주)', '(주)오예스', '하드릴', '레인주니어 픽쳐스'], dtype=object))

# %% [markdown]
# ##### 3. 영화 유형

# %% [markdown]
# - 영화유형 데이터
#   - 1개의 유형만 가지고 있으므로 해당 컬럼은 삭제한다.

# %%
movie['영화유형'].unique()
# Out:
# array(['개봉영화'], dtype=object)

# %%
movie.drop('영화유형', axis=1, inplace=True)

# %%
movie.columns
# Out:
# Index(['영화명', '감독', '배급사', '개봉일', '영화형태', '국적', '전국스크린수', '전국매출액', '전국관객수',
#        '장르', '등급', '영화구분'],
#       dtype='object')

# %% [markdown]
# ##### 4. 영화형태

# %% [markdown]
# - 영화형태 데이터
#   - 4개의 유형을 가진 데이터로 이상한 값은 없으므로 넘어간다.
#   - 장편이 압도적으로 많은 것을 볼 수 있다.

# %%
movie['영화형태'].unique()
# Out:
# array(['장편', '옴니버스', '단편', '기타'], dtype=object)

# %%
movie['영화형태'].value_counts()
# Out:
# 장편      13262
# 옴니버스       44
# 단편          1
# 기타          1
# Name: 영화형태, dtype: int64

# %%
ordered_index = movie['영화형태'].value_counts().sort_values(ascending=False).index
plt.figure(figsize=(5, 3))
sns.countplot(data = movie, y = '영화형태', order=ordered_index)
plt.show()

# %% [markdown]
# ##### 5. 국적

# %% [markdown]
# - 국적 데이터
#   - 총 68개의 유형이 있다.
#   - 국적별 영화수의 top3과 나머지의 차이가 많으므로 나머지 국가를 기타로 변경한다.

# %%
len(movie['국적'].unique()), movie['국적'].unique()
# Out:
# (68,
#  array(['한국', '미국', '일본', '영국', '프랑스', '벨기에', '아이슬란드', '독일', '스페인', '러시아',
#         '아일랜드', '남아프리카공화국', '인도', '대만', '핀란드', '중국', '스웨덴', '이탈리아', '호주',
#         '덴마크', '캐나다', '기타', '아르헨티나', '홍콩', '페루', '태국', '우크라이나', '노르웨이',
#         '오스트리아', '터키', '멕시코', '뉴질랜드', '체코', '그리스', '폴란드', '칠레', '헝가리',
#         '말레이시아', '인도네시아', '브라질', '네덜란드', '이스라엘', '이란', '싱가포르', '루마니아',
#         '포르투갈', '스위스', '팔레스타인', '콜롬비아', '에스토니아', '아랍에미리트연합국정부', '베트남',
#         '몽고', '불가리아', '부탄', '슬로바키아', '쿠바', '크로아티아', '베네수엘라', '카자흐스탄',
#         '우루과이', '몰타', '필리핀', '세르비아', '이라크', '마케도니아', '모로코', '우즈베키스탄'],
#        dtype=object))

# %%
movie['국적'].value_counts().sort_values(ascending=False)[:10]
# Out:
# 한국     3954
# 일본     3912
# 미국     2668
# 프랑스     436
# 영국      424
# 중국      340
# 독일      224
# 캐나다     172
# 스페인     131
# 홍콩      130
# Name: 국적, dtype: int64

# %%
top10 = movie['국적'].value_counts().sort_values(ascending=True)[-10:].copy()
plt.figure(figsize=(7, 3))
plt.barh(top10.index, top10.values)
plt.show()

# %%
# 국적 데이터 변경
for idx, row in movie.iterrows():
    if  row['국적'] not in ['한국', '일본', '미국']:
        movie['국적'][idx] = '기타'

# %% [markdown]
# - 총 4개의 유형만 남은 것을 볼 수 있다.

# %%
movie['국적'].value_counts()
# Out:
# 한국    3954
# 일본    3912
# 기타    2774
# 미국    2668
# Name: 국적, dtype: int64

# %% [markdown]
# ##### 6. 장르

# %% [markdown]
# - 장르 데이터
#   - 결측치를 기타로 변경한 뒤이기 때문에 `KOBIS 장르 분포 통계` 기준과 같은 장르를 가진다.
#   - count를 확인해본 결과 멜로/로맨스가 가장 높은 수치를 기록하였다.

# %%
len(movie['장르'].unique()), movie['장르'].unique()
# Out:
# (21,
#  array(['사극', '코미디', '판타지', '드라마', '액션', '애니메이션', '어드벤처', 'SF', '범죄', '전쟁',
#         '미스터리', '멜로/로맨스', '스릴러', '다큐멘터리', '공포(호러)', '뮤지컬', '가족', '공연',
#         '기타', '서부극(웨스턴)', '성인물(에로)'], dtype=object))

# %%
ordered_index = movie['장르'].value_counts().sort_values(ascending=False).index
plt.figure(figsize=(10, 5))
sns.countplot(data = movie, y = '장르', order=ordered_index)
plt.show()

# %% [markdown]
# ##### 7. 등급

# %% [markdown]
# - 등급 데이터
#   - 10개의 유형이 있고 복수의 데이터가 있는 경우를 확인하였다.
#   - 다수의 등급을 분리하여 1개의 대표등급으로 변경해준다.
#     - 다수의 등급이 있는 경우 시청 연령이 작은 쪽을 선택해준다.

# %%
len(movie['등급'].unique()), movie['등급'].unique()
# Out:
# (10,
#  array(['15세이상관람가', '12세이상관람가', '전체관람가', '청소년관람불가', '청소년관람불가,15세이상관람가',
#         '15세관람가', '12세이상관람가,15세이상관람가', '12세이상관람가,전체관람가', '15세이상관람가,전체관람가',
#         '15세관람가,12세이상관람가'], dtype=object))

# %%
# 다수의 등급 데이터 변경
for idx, row in movie.iterrows():
    if ',' in row['등급']:
        ratings = row['등급'].split(',')
        # 전체, 12, 15, 청소년관람불가 순
        if '전체' in ratings:
            movie['등급'][idx] = '전체관람가'
        elif '12' in ratings:
            movie['등급'][idx] = '12세관람가'
        elif '15' in ratings:
            movie['등급'][idx] = '15세관람가'
        else:
            movie['등급'][idx] = '청소년관람불가'
    else:
        movie['등급'][idx] = movie['등급'][idx].replace('이상', '')

# %% [markdown]
# - 총 4개의 유형으로 정리하였다.
#   - 15세관람가, 12세관람가, 전체관람가, 청소년관람불가

# %%
len(movie['등급'].unique()), movie['등급'].unique()
# Out:
# (4, array(['15세관람가', '12세관람가', '전체관람가', '청소년관람불가'], dtype=object))

# %%
ordered_index = movie['등급'].value_counts().sort_values(ascending=False).index
plt.figure(figsize=(5, 3))
sns.countplot(data = movie, y = '등급', order=ordered_index)
plt.show()

# %% [markdown]
# ##### 8. 영화구분

# %% [markdown]
# - 영화구분 데이터
#   - 2개의 유형이 있고 일반영화가 2배 정도 더 많은 수치를 기록했다.

# %%
len(movie['영화구분'].unique()), movie['영화구분'].unique()
# Out:
# (2, array(['일반영화', '독립/예술영화'], dtype=object))

# %%
plt.figure(figsize=(5, 5))
sns.countplot(data = movie, x = '영화구분')
plt.show()

# %% [markdown]
# ##### 데이터 임시 저장

# %%
# 데이터 임시 저장
# movie.to_excel('../data/전체영화데이터_2_category.xls', encoding='utf-8')

# %% [markdown]
# #### 영화 데이터 수치형 확인

# %% [markdown]
# - 데이터 유형
#   - 날짜형(1개) : 개봉일('YYYY-MM-DD')
#   - 수치형(3개) : 전국스크린수, 전국매출액, 전국관객수
#   - 범주형(8개) : 영화명, 감독, 배급사, 영화형태, 국적, 장르, 등급, 영화구분

# %%
movie[['전국스크린수', '전국매출액', '전국관객수']].describe().astype('int64')
# Out:
#        전국스크린수         전국매출액     전국관객수
# count   13308         13308     13308
# mean       86    1141088085    143850
# std       224    6475225188    808506
# min         0             0         0
# 25%         1          6000         1
# 50%         2        300000        61
# 75%        34      34914520      4845
# max      2835  139647979516  17613682

# %% [markdown]
# - 전국스크린수는 34개가 75% 지점이지만 최대값은 2835개인 만큼 불균형 현상이 있는 것을 볼 수 있다.

# %%
sns.distplot(movie['전국스크린수']);

# %% [markdown]
# - 매출액 또한 편향된 데이터를 가진 것을 볼 수 있다.

# %%
sns.distplot(movie['전국매출액']);

# %% [markdown]
# - 관객수 또한 편향된 데이터를 보이며 전체에 비해 소수의 영화만이 흥행에 성공한다는 것을 볼 수 있다.

# %%
sns.distplot(movie['전국관객수']);

# %% [markdown]
# #### 영화 데이터 조절

# %% [markdown]
# - 수치형 데이터의 경우 불균형이 심하기 때문에 약간의 조절을 해준다.
#   - 전국관객수 1000명 초과
#   - 전국스크린수 50개 초과
#   - 총 데이터 2950개

# %%
movie[(movie['전국관객수'] > 1000) & (movie['전국스크린수'] > 50)].count()
# Out:
# 영화명       2950
# 감독        2950
# 배급사       2950
# 개봉일       2950
# 영화형태      2950
# 국적        2950
# 전국스크린수    2950
# 전국매출액     2950
# 전국관객수     2950
# 장르        2950
# 등급        2950
# 영화구분      2950
# dtype: int64

# %%
movie_resize = movie[(movie['전국관객수'] > 1000) & (movie['전국스크린수'] > 50)]
movie_resize.head(3)
# Out:
#           영화명   감독        배급사        개봉일 영화형태  국적  전국스크린수         전국매출액  \
# 순번
# 1          명량  김한민  (주)씨제이이엔엠 2014-07-30   장편  한국    1587  135748398910
# 2        극한직업  이병헌  (주)씨제이이엔엠 2019-01-23   장편  한국    1978  139647979516
# 3   신과함께-죄와 벌  김용화         롯데 2017-12-20   장편  한국    1912  115698654137
#
#        전국관객수   장르      등급  영화구분
# 순번
# 1   17613682   사극  15세관람가  일반영화
# 2   16264944  코미디  15세관람가  일반영화
# 3   14410754  판타지  12세관람가  일반영화

# %% [markdown]
# - 중복값 확인
#   - 중복값의 수가 많았던 `감독`, `배급사` 컬럼만 확인
#   - 감독의 수 : 5987명 -> 1965명
#   - 배급사의 수 : 597개 -> 177개

# %%
len(movie_resize['감독'].unique()), movie_resize['감독'].unique()
# Out:
# (1965,
#  array(['김한민', '이병헌', '김용화', ..., '마이클 데미언', '줄리엔 라페뉴', '정형석'],
#        dtype=object))

# %%
len(movie_resize['배급사'].unique()), movie_resize['배급사'].unique()
# Out:
# (177,
#  array(['(주)씨제이이엔엠', '롯데', '디즈니', '(주)쇼박스', '(주)넥스트엔터테인먼트월드(NEW)', '소니픽쳐스',
#         '워너브러더스 코리아(주)', '이십세기폭스코리아(주)', '메가박스', '유니버설픽쳐스인터내셔널 코리아(유)',
#         'CGV', '판씨네마(주)', '(주)와우픽쳐스', '(주)에이스메이커무비웍스', '(주)스튜디오디에이치엘',
#         '아이러브시네마', '(주)인벤트스톤', '필라멘트픽쳐스', '오퍼스픽쳐스(유)', '에스케이플래닛(주)',
#         '씨네그루(주)다우기술', '(주)메리크리스마스', 'CJ ENM', '(주)제이앤씨미디어그룹',
#         '씨너스엔터테인먼트(주)', '(주)영화사 그램', '주식회사 해리슨앤컴퍼니', '워터홀컴퍼니(주)',
#         '(주)키다리이엔티', '(주)디스테이션', '(주)시너지하우스 (시너지)', '(주)에스비에스콘텐츠허브',
#         '(주)누리픽쳐스', '글뫼 주식회사', '(주)시네마서비스', '(주)스마일이엔티', '(주)올스타엔터테인먼트',
#         '(주)화앤담이엔티', '(주)리틀빅픽쳐스', '(주)피터팬픽쳐스', '(주)미디어데이', '(주)싸이더스',
#         '유나이티드픽처스(주)', '주식회사 우리네트웍스', '(주)나이너스엔터테인먼트', '(주)이수C&E',
#         '(주)엣나인필름', 'TCO(주)더콘텐츠온', '영화사올(주)', '(주)콘텐츠 난다긴다',
#         '(주)마인스 엔터테인먼트', '오드', '주식회사 마운틴픽쳐스', '(주)팝엔터테인먼트', '주식회사 더쿱',
#         '(주)프레인글로벌', '(주)삼백상회', '(주)박수엔터테인먼트', '타임스토리그룹(주)', '(주)팝파트너스',
#         '(재)CBS', '예지림엔터테인먼트', '(주)영화사 빅', '(주)홈초이스', '㈜코리아스크린', '(주)그노스',
#         '(주)이놀미디어', '(주)까멜리아이엔티', '(주)모멘텀엔터테인먼트', '(주)키위미디어그룹', '(주)티캐스트',
#         '(주)셀트리온엔터테인먼트', '(주)대명문화공장', '에스케이텔레콤(주)', '에이원엔터테인먼트',
#         '그린나래미디어(주)', '(주)영화사 진진', '와이드 릴리즈(주)', '(주)아이코닉스', '(주)콘텐츠판다',
#         '찬란', '커넥트픽쳐스(주)', 'KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', '팝엔터테인먼트',
#         '동우에이앤이(주)', '(주)삼지애니메이션', '(주)지어소프트', '블루미지', '(주)트리플픽쳐스',
#         '(주)영화사오원', '씨제이포디플렉스 주식회사', '(주)드림팩트엔터테인먼트', '(주)무빙픽쳐스컴퍼니',
#         '(주)케이티알파', '파이오니아21', '(주)더블앤조이픽쳐스', '(주)크리픽쳐스', '(주)애니플러스', '기타',
#         '(주)라이크콘텐츠', '(주)영화제작전원사', '(유)조이앤시네마', '(주)포켓몬코리아',
#         '(주)영화특별시에스엠씨', '(주)와이즈베이', '이언픽쳐스', '(주)스톰픽쳐스코리아', '(주)브리즈픽처스',
#         '㈜T-JOY', '대원미디어(주)', '힘컨텐츠(주)', '(주)퍼스트런', 'THE 픽쳐스', '(주)미디어캐슬',
#         '(주)다자인소프트', '주식회사 온 피크', '(주)메인타이틀픽쳐스', '주식회사 디에스이이디',
#         '(주)엠제이픽쳐스', '(주)아이엠비씨', '(주)인디플러그', '(주)시네마달', '골든타이드픽처스(주)',
#         '㈜영화사 백두대간', '(주)에스와이코마드', '(주)디오시네마', '브릿지웍스 엔터테인먼트(주)',
#         '(주)머스트씨무비릴리징컴퍼니', '(주)씨네포트', '(주)빅웨이브시네마', '플레이리스트(주)', '아이 엠',
#         '㈜케이디미디어', '(주)팬엔터테인먼트', '(주)버킷스튜디오', '(주)좋은 하늘', 'KBS 미디어', '오키넷',
#         '주식회사 씨네룩스', '(주)블룸즈베리파트너스', '주식회사 왓챠', '(주)대교 미디어콘텐츠사업본부',
#         '㈜인디스토리', '영화사 마농(주)', '스튜디오 프로그레시브 인큐베이터', '(주)미디어로그',
#         '주식회사 풍경소리', '(주)명필름', '(주)머스트씨무비', '영화사 풀', '알토미디어(주)',
#         '스마트스터디(주)', '(주)소나무픽쳐스', '(주)중헌홀딩스', '(주)알앤오엔터테인먼트',
#         '주식회사 블루필름웍스', '(주)영화사 조제', '(주)에이원엔터테인먼트', '(주)마노엔터테인먼트',
#         '(주)비싸이드 픽쳐스', '(주)김기덕 필름', '(주)블룸즈베리리소시스리미티드', '(주)영화사 안다미로',
#         '(주)미로스페이스', '(주)영화사선', '프리비젼엔터테인먼트', '(주)스튜디오 보난자', '노바엔터테인먼트',
#         '어뮤즈', '영화사 민들레', '(주)에이썸엔터테인먼트', '(주)률필름', 'M&M 인터내셔널',
#         '(주)유로커뮤니케이션', '(주)영화사메이플러스', '(주)노바이앤티', '윤스'], dtype=object))

# %% [markdown]
# #### 수치형 데이터 상관관계 확인

# %% [markdown]
# - 수치형 데이터들 간의 상관관계 확인
#   - 전국매출액과 전국 관객수는 1인 것을 확인할 수 있다.
#   - 이는 매출액과 관객수 모두 `발권 데이터`를 기준으로하기 때문이다. 따라서 전국 매출액 컬럼은 삭제한다.
#   - 전국스크린수와 전국관객수는 강한 상관관계가 있음을 볼 수 있다.

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(data=movie_resize[['전국스크린수', '전국매출액', '전국관객수']].corr(), fmt='.2f', annot=True)
plt.show()

# %%
movie_resize.drop('전국매출액', axis=1, inplace=True)

# %%
# 임시 저장
# movie_resize.to_excel('../data/전체영화데이터_3_resize.xls', encoding='utf-8')

# %% [markdown]
# #### 범주형 데이터 정리 1

# %% [markdown]
# - 범주형 데이터 중 `감독`, `배급사`는 각 유형의 수가 많아 더미 변수를 만들기 어렵다 판단하였습니다.
# - 감독, 배급사의 영화 흥행 실적 여부를 변수로 새로 만들어 준다.
# - **네이버 영화 데이터를 결합한 후 설정하기 위해 이후에 작업**

# %% [markdown]
# #### 범주형 데이터 정리 2

# %% [markdown]
# - 범주형 데이터 중 `영화형태`, `국적`, `장르`, `등급`, `영화구분`은 더미 변수를 만들어 대체한다.
#   - sklearn의 OneHotEncoder을 이용해 더미 변수를 만들 수 있다.
#   - 대체로 Pandas의 `get_dummies()`를 이용할 수 있다.
#   - Pandas의 함수를 이용해 더미 변수를 만들었다.
#   - 더미 변수의 생성으로 컬럼의 수는 39개로 늘어났다.

# %%
movie_dummies = pd.get_dummies(data=movie_resize, columns=['영화형태','국적','장르','등급','영화구분'])
movie_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 1 to 4697
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   영화명           2950 non-null   object
#  1   감독            2950 non-null   object
#  2   배급사           2950 non-null   object
#  3   개봉일           2950 non-null   datetime64[ns]
#  4   전국스크린수        2950 non-null   int64
#  5   전국관객수         2950 non-null   int64
#  6   영화형태_단편       2950 non-null   uint8
#  7   영화형태_옴니버스     2950 non-null   uint8
#  8   영화형태_장편       2950 non-null   uint8
#  9   국적_기타         2950 non-null   uint8
#  10  국적_미국         2950 non-null   uint8
#  11  국적_일본         2950 non-null   uint8
#  12  국적_한국         2950 non-null   uint8
#  13  장르_SF         2950 non-null   uint8
#  14  장르_가족         2950 non-null   uint8
#  15  장르_공연         2950 non-null   uint8
#  16  장르_공포(호러)     2950 non-null   uint8
#  17  장르_기타         2950 non-null   uint8
#  18  장르_다큐멘터리      2950 non-null   uint8
#  19  장르_드라마        2950 non-null   uint8
#  20  장르_멜로/로맨스     2950 non-null   uint8
#  21  장르_뮤지컬        2950 non-null   uint8
#  22  장르_미스터리       2950 non-null   uint8
#  23  장르_범죄         2950 non-null   uint8
#  24  장르_사극         2950 non-null   uint8
#  25  장르_서부극(웨스턴)   2950 non-null   uint8
#  26  장르_스릴러        2950 non-null   uint8
#  27  장르_애니메이션      2950 non-null   uint8
#  28  장르_액션         2950 non-null   uint8
#  29  장르_어드벤처       2950 non-null   uint8
#  30  장르_전쟁         2950 non-null   uint8
#  31  장르_코미디        2950 non-null   uint8
#  32  장르_판타지        2950 non-null   uint8
#  33  등급_12세관람가     2950 non-null   uint8
#  34  등급_15세관람가     2950 non-null   uint8
#  35  등급_전체관람가      2950 non-null   uint8
#  36  등급_청소년관람불가    2950 non-null   uint8
#  37  영화구분_독립/예술영화  2950 non-null   uint8
#  38  영화구분_일반영화     2950 non-null   uint8
# dtypes: datetime64[ns](1), int64(2), object(3), uint8(33)
# memory usage: 256.4+ KB

# %%
# 임시 저장
# movie_dummies.to_excel('../data/전체영화데이터_4_dummy.xls', encoding='utf-8')

# %% [markdown]
# ### 2. 네이버 영화

# %% [markdown]
# #### 네이버 영화 데이터 결측치

# %% [markdown]
# - 2011 ~ 2020년 데이터를 크롤링하여 총 2414개의 데이터이며 결측치는 없다.

# %%
naver_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2414 entries, 0 to 2413
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   영화명     2414 non-null   object
#  1   감독      2414 non-null   object
#  2   주연배우    2414 non-null   object
#  3   평점      2414 non-null   float64
#  4   평가자수    2414 non-null   int64
#  5   상영시간    2414 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 132.0+ KB

# %% [markdown]
# #### 네이버 영화 범주형 데이터

# %% [markdown]
# - 데이터 유형
#   - 수치형(3개) : 평점, 평가자수, 상영시간
#   - 범주형(3개) : 영화명, 감독, 주연배우
# - 조금씩 중복이 있는 것을 확인할 수 있다.
# - 영화명과 감독명을 합친 결과로는 중복값이 없으므로 해당값을 사용하여 `영화 데이터`와 결합한다.

# %%
category_cols = ['영화명','감독','주연배우', '영화+감독']
naver_test = naver_movie.copy()
naver_test['영화+감독'] = [row['영화명']+row['감독'] for idx, row in naver_test.iterrows()]
# 범주형 데이터의 unique 확인
for col in category_cols:
    print('컬럼 [{}] UNIQUE : {}'.format(col, len(naver_test[col].unique())))
# Out:
# 컬럼 [영화명] UNIQUE : 2403
# 컬럼 [감독] UNIQUE : 1631
# 컬럼 [주연배우] UNIQUE : 2325
# 컬럼 [영화+감독] UNIQUE : 2414

# %% [markdown]
# ##### 1. 주연배우

# %% [markdown]
# - naver_movie의 `주연배우` 컬럼의 값을 문자열로 되어있기 때문에 `literal_eval` 함수를 이용해 리스트형으로 만들어준다.
# - 전체 배우의 중복 제거값을 확인해보면 총 4255명의 배우가 확인된다.
# - 너무 많은 수 이므로 주연배우 중 첫 번째로 나오는 배우만을 선택한다.
#   - 첫 번째로 나오는 배우를 가장 중요한 출연진으로 생각한다.

# %%
from ast import literal_eval

# literal_evel : 문자열 그대로 파이썬 명령을 실행시켜주는 함수
# 예시---------------------------------------
# 문자열 : "['문자열1', '문자열2', 22, '33']"
# 리스트 : ['문자열1', '문자열2', 22, '33']
actors = set( actor.strip() for i, row in naver_movie.iterrows() for actor in literal_eval(row['주연배우']))
actors.remove('')   # 공백 제거
actors = list(actors)

# %%
len(actors), actors[:5]
# Out:
# (4255, ['와타나베 켄', '김유나', '크리스토프 왈츠', '누마쿠라 마나미', '정두언'])

# %% [markdown]
# - 주연 배우 중 대표를 선정하여 변경해준다.
# - 결측치가 없음을 다시 확인해준다.

# %%
# 대표 주연 배우 선정
actors = []
for i, row in naver_movie.iterrows():
    for actor in literal_eval(row['주연배우']):
        if actor:
            actors.append(actor.strip())
            break
naver_movie.loc[:, '주연배우'] = actors

# %%
naver_movie.isnull().sum()
# Out:
# 영화명     0
# 감독      0
# 주연배우    0
# 평점      0
# 평가자수    0
# 상영시간    0
# dtype: int64

# %%
# 임시 저장
# naver_movie.to_excel('../data/네이버_영화_데이터_1_actor.xlsx')

# %% [markdown]
# #### 결합

# %%
naver_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2414 entries, 0 to 2413
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   영화명     2414 non-null   object
#  1   감독      2414 non-null   object
#  2   주연배우    2414 non-null   object
#  3   평점      2414 non-null   float64
#  4   평가자수    2414 non-null   int64
#  5   상영시간    2414 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 132.0+ KB

# %%
movie_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2950 entries, 1 to 4697
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   영화명           2950 non-null   object
#  1   감독            2950 non-null   object
#  2   배급사           2950 non-null   object
#  3   개봉일           2950 non-null   datetime64[ns]
#  4   전국스크린수        2950 non-null   int64
#  5   전국관객수         2950 non-null   int64
#  6   영화형태_단편       2950 non-null   uint8
#  7   영화형태_옴니버스     2950 non-null   uint8
#  8   영화형태_장편       2950 non-null   uint8
#  9   국적_기타         2950 non-null   uint8
#  10  국적_미국         2950 non-null   uint8
#  11  국적_일본         2950 non-null   uint8
#  12  국적_한국         2950 non-null   uint8
#  13  장르_SF         2950 non-null   uint8
#  14  장르_가족         2950 non-null   uint8
#  15  장르_공연         2950 non-null   uint8
#  16  장르_공포(호러)     2950 non-null   uint8
#  17  장르_기타         2950 non-null   uint8
#  18  장르_다큐멘터리      2950 non-null   uint8
#  19  장르_드라마        2950 non-null   uint8
#  20  장르_멜로/로맨스     2950 non-null   uint8
#  21  장르_뮤지컬        2950 non-null   uint8
#  22  장르_미스터리       2950 non-null   uint8
#  23  장르_범죄         2950 non-null   uint8
#  24  장르_사극         2950 non-null   uint8
#  25  장르_서부극(웨스턴)   2950 non-null   uint8
#  26  장르_스릴러        2950 non-null   uint8
#  27  장르_애니메이션      2950 non-null   uint8
#  28  장르_액션         2950 non-null   uint8
#  29  장르_어드벤처       2950 non-null   uint8
#  30  장르_전쟁         2950 non-null   uint8
#  31  장르_코미디        2950 non-null   uint8
#  32  장르_판타지        2950 non-null   uint8
#  33  등급_12세관람가     2950 non-null   uint8
#  34  등급_15세관람가     2950 non-null   uint8
#  35  등급_전체관람가      2950 non-null   uint8
#  36  등급_청소년관람불가    2950 non-null   uint8
#  37  영화구분_독립/예술영화  2950 non-null   uint8
#  38  영화구분_일반영화     2950 non-null   uint8
# dtypes: datetime64[ns](1), int64(2), object(3), uint8(33)
# memory usage: 256.4+ KB

# %%
movie_dummies.shape, naver_movie.shape
# Out:
# ((2950, 39), (2414, 6))

# %%
movie_merge = pd.merge(movie_dummies, naver_movie, how='inner', on=['영화명', '감독'])

# %%
movie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2393 entries, 0 to 2392
# Data columns (total 43 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   영화명           2393 non-null   object
#  1   감독            2393 non-null   object
#  2   배급사           2393 non-null   object
#  3   개봉일           2393 non-null   datetime64[ns]
#  4   전국스크린수        2393 non-null   int64
#  5   전국관객수         2393 non-null   int64
#  6   영화형태_단편       2393 non-null   uint8
#  7   영화형태_옴니버스     2393 non-null   uint8
#  8   영화형태_장편       2393 non-null   uint8
#  9   국적_기타         2393 non-null   uint8
#  10  국적_미국         2393 non-null   uint8
#  11  국적_일본         2393 non-null   uint8
#  12  국적_한국         2393 non-null   uint8
#  13  장르_SF         2393 non-null   uint8
#  14  장르_가족         2393 non-null   uint8
#  15  장르_공연         2393 non-null   uint8
#  16  장르_공포(호러)     2393 non-null   uint8
#  17  장르_기타         2393 non-null   uint8
#  18  장르_다큐멘터리      2393 non-null   uint8
#  19  장르_드라마        2393 non-null   uint8
#  20  장르_멜로/로맨스     2393 non-null   uint8
#  21  장르_뮤지컬        2393 non-null   uint8
#  22  장르_미스터리       2393 non-null   uint8
#  23  장르_범죄         2393 non-null   uint8
#  24  장르_사극         2393 non-null   uint8
#  25  장르_서부극(웨스턴)   2393 non-null   uint8
#  26  장르_스릴러        2393 non-null   uint8
#  27  장르_애니메이션      2393 non-null   uint8
#  28  장르_액션         2393 non-null   uint8
#  29  장르_어드벤처       2393 non-null   uint8
#  30  장르_전쟁         2393 non-null   uint8
#  31  장르_코미디        2393 non-null   uint8
#  32  장르_판타지        2393 non-null   uint8
#  33  등급_12세관람가     2393 non-null   uint8
#  34  등급_15세관람가     2393 non-null   uint8
#  35  등급_전체관람가      2393 non-null   uint8
#  36  등급_청소년관람불가    2393 non-null   uint8
#  37  영화구분_독립/예술영화  2393 non-null   uint8
#  38  영화구분_일반영화     2393 non-null   uint8
#  39  주연배우          2393 non-null   object
#  40  평점            2393 non-null   float64
#  41  평가자수          2393 non-null   int64
#  42  상영시간          2393 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4), uint8(33)
# memory usage: 282.8+ KB

# %%
# 결측치 확인
cols = ['주연배우','평점','평가자수', '상영시간']
movie_merge[cols].isnull().sum()
# Out:
# 주연배우    0
# 평점      0
# 평가자수    0
# 상영시간    0
# dtype: int64

# %%
# 임시 저장
# movie_merge.to_excel('../data/전체영화데이터_5_merge.xls')

# %% [markdown]
# ### 3. 통합 데이터

# %% [markdown]
# #### 범주형 데이터 정리

# %% [markdown]
# - 범주형 데이터 중 `감독`, `배급사`, `주연배우`는 각 유형의 수가 많아 더미 변수를 만들기 어렵다 판단하였습니다.
# - 감독, 배급사, 주연배우의 영화 흥행 실적 여부를 변수로 새로 만들어 준다.
#   - 흥행 실적 여부는 관객수 기준 top 200(전체 데이터의 약 10%) 여부로 설정합니다.

# %%
# 전체 데이터 수, 감독수, 배급사 수, 주연배우 수
len(movie_merge), len(movie_merge['감독'].unique()), len(movie_merge['배급사'].unique()), len(movie_merge['주연배우'].unique())
# Out:
# (2393, 1619, 163, 1465)

# %%
# 감독, 배급사의 흥행 여부 초기값 설정
movie_final = movie_merge.copy()
movie_final['감독_흥행'] = [0 for _ in range(len(movie_merge))]
movie_final['배급사_흥행'] = [0 for _ in range(len(movie_merge))]
movie_final['주연배우_흥행'] = [0 for _ in range(len(movie_merge))]

cols = ['감독', '배급사', '주연배우', '감독_흥행', '배급사_흥행', '주연배우_흥행']
movie_final[cols].head()
# Out:
#     감독        배급사 주연배우  감독_흥행  배급사_흥행  주연배우_흥행
# 0  김한민  (주)씨제이이엔엠  김한민      0       0        0
# 1  이병헌  (주)씨제이이엔엠  류승룡      0       0        0
# 2  김용화         롯데  하정우      0       0        0
# 3  윤제균  (주)씨제이이엔엠  황정민      0       0        0
# 4  류승완  (주)씨제이이엔엠  황정민      0       0        0

# %%
# 흥행 감독, 배급사 추출
directors = list(movie_final.sort_values(by='전국관객수', ascending=False)['감독'][:200].unique())
distributors = list(movie_final.sort_values(by='전국관객수', ascending=False)['배급사'][:200].unique())
actors = list(movie_final.sort_values(by='전국관객수', ascending=False)['주연배우'][:200].unique())

len(directors), len(distributors), len(actors)
# Out:
# (145, 18, 143)

# %% [markdown]
# - 흥행 여부 표시

# %%
# 감독 흥행 표시
for director in directors:
    index = movie_final[movie_final['감독'] == director].index
    movie_final['감독_흥행'][index] = [1] * len(index)
# 배급사 흥행 표시
for distributor in distributors:
    index = movie_final[movie_final['배급사'] == distributor].index
    movie_final['배급사_흥행'][index] = [1] * len(index)
# 주연배우 흥행 표시
for actor in actors:
    index = movie_final[movie_final['주연배우'] == actor].index
    movie_final['주연배우_흥행'][index] = [1] * len(index)

movie_final[cols].head(3)
# Out:
#     감독        배급사 주연배우  감독_흥행  배급사_흥행  주연배우_흥행
# 0  김한민  (주)씨제이이엔엠  김한민      1       1        1
# 1  이병헌  (주)씨제이이엔엠  류승룡      1       1        1
# 2  김용화         롯데  하정우      1       1        1

# %% [markdown]
# - 흥행 여부 카운트 확인

# %%
movie_final['감독_흥행'].value_counts()
# Out:
# 0    2029
# 1     364
# Name: 감독_흥행, dtype: int64

# %%
movie_final['배급사_흥행'].value_counts()
# Out:
# 0    1239
# 1    1154
# Name: 배급사_흥행, dtype: int64

# %%
movie_final['주연배우_흥행'].value_counts()
# Out:
# 0    1914
# 1     479
# Name: 주연배우_흥행, dtype: int64

# %%
# 임시 저장
# movie_final.to_excel('../data/전체영화데이터_6_success.xls', encoding='utf-8')

# %% [markdown]
# ## ◾모델 수립 및 예측

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. 데이터 분리

# %% [markdown]
# #### 2020년 데이터 분리

# %% [markdown]
# - 먼저 코로나 이전의 데이터로 학습시키기 위해 2020년 데이터를 분리한다.
#   - 2020년 : 234개

# %%
movie_2020 = movie_final.query('개봉일 >= "20200101"')
print(len(movie_2020))
movie_2020.head(3)
# Out:
# 234
#              영화명   감독                  배급사        개봉일  전국스크린수    전국관객수  \
# 84       남산의 부장들  우민호               (주)쇼박스 2020-01-22    1659  4750104
# 97   다만 악에서 구하소서  홍원찬            (주)씨제이이엔엠 2020-08-05    1998  4352669
# 113           반도  연상호  (주)넥스트엔터테인먼트월드(NEW) 2020-07-15    2575  3812080
#
#      영화형태_단편  영화형태_옴니버스  영화형태_장편  국적_기타  ...  등급_청소년관람불가  영화구분_독립/예술영화  \
# 84         0          0        1      0  ...           0             0
# 97         0          0        1      0  ...           0             0
# 113        0          0        1      0  ...           0             0
#
#      영화구분_일반영화  주연배우    평점   평가자수  상영시간  감독_흥행  배급사_흥행  주연배우_흥행
# 84           1   이병헌  7.47  18168   114      1       1        1
# 97           1   황정민  7.61  21397   108      1       1        1
# 113          1   강동원  5.64  31323   116      1       1        1
#
# [3 rows x 46 columns]

# %%
# 임시 저장
# movie_2020.to_excel('../data/2020영화데이터_final.xls', encoding='utf-8')

# %% [markdown]
# #### 2011년~2019년 변수와 라벨 분리

# %% [markdown]
# - 더미가 있는 테이블에서 2011~2019년의 데이터를 추출한다.
#   - 2011년~2019년 : 2159개

# %%
movie_2011_2019 = movie_final.query('개봉일 < "2020-01-01"')
print(len(movie_2011_2019))
movie_2011_2019.head(3)
# Out:
# 2159
#          영화명   감독        배급사        개봉일  전국스크린수     전국관객수  영화형태_단편  영화형태_옴니버스  \
# 0         명량  김한민  (주)씨제이이엔엠 2014-07-30    1587  17613682        0          0
# 1       극한직업  이병헌  (주)씨제이이엔엠 2019-01-23    1978  16264944        0          0
# 2  신과함께-죄와 벌  김용화         롯데 2017-12-20    1912  14410754        0          0
#
#    영화형태_장편  국적_기타  ...  등급_청소년관람불가  영화구분_독립/예술영화  영화구분_일반영화  주연배우    평점  \
# 0        1      0  ...           0             0          1   김한민  5.06
# 1        1      0  ...           0             0          1   류승룡  8.51
# 2        1      0  ...           0             0          1   하정우  7.83
#
#     평가자수  상영시간  감독_흥행  배급사_흥행  주연배우_흥행
# 0    135    95      1       1        1
# 1  47558   111      1       1        1
# 2  57870   139      1       1        1
#
# [3 rows x 46 columns]

# %%
# 임시저장
# movie_2011_2019.to_excel('../data/2011_2019영화데이터_final.xls', encoding='utf-8')

# %% [markdown]
# - X : ['영화명', '감독', '주연배우', '배급사', '개봉일', '전국관객수'] 제외 컬럼
# - y : ['전국관객수'] 컬럼
#   - 값이 크기 때문에 '전국관객수 / 1000'을 사용한다.
# - **`평가자수` 컬럼은 영화를 보고 온 사람이 많으므로 코로나 영향을 받았을 것이라 판단해 제외하였습니다.**

# %%
not_used = ['영화명', '감독', '주연배우', '평가자수','배급사', '개봉일', '전국관객수']
X = movie_2011_2019.drop(not_used, axis=1)
y = movie_2011_2019['전국관객수'] / 1000

X.shape, y.shape
# Out:
# ((2159, 39), (2159,))

# %% [markdown]
# #### 훈련용, 테스트용 데이터 분리

# %% [markdown]
# - sklearn의 `train_test_split`을 사용하여 분리한다.
#   - `2011년~2019년`의 20%를 테스트용으로 사용한다.
#   - train : 1727개
#   - test : 432개

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
X_train.shape, y_train.shape
# Out:
# ((1727, 39), (1727,))

# %%
X_test.shape, y_test.shape
# Out:
# ((432, 39), (432,))

# %% [markdown]
# ### 2. 모델 수립 및 예측

# %% [markdown]
# #### 선형 회귀 모델

# %% [markdown]
# - 선형 회귀 모델 학습

# %%
lr_clf = LinearRegression()
lr_clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# - 예측 및 모델 평가
#   - 모델 평가는 RMSE(Root Mean Square Error)을 사용한다.

# %%
pred_tr = lr_clf.predict(X_train)
pred_test = lr_clf.predict(X_test)
rmse_tr = (np.sqrt(mean_squared_error(y_train, pred_tr)))
rmse_test = (np.sqrt(mean_squared_error(y_test, pred_test)))

print('RMSE of Train Data : {}'.format(rmse_tr))
print('RMSE of Test Data : {}'.format(rmse_test))
# Out:
# RMSE of Train Data : 1041.1150283139289
# RMSE of Test Data : 1087.4318569187596

# %% [markdown]
# - 성능 평가(참값, 예측값 비교)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, pred_test)
plt.xlabel('Real Count(1000명)')
plt.ylabel('Predicted Count(1000명)')
plt.grid(True)
plt.title('Real vs Predicted')
plt.plot([0, 15000], [0, 15000], 'r')
plt.show()

# %% [markdown]
# #### 랜덤포레스트 회귀 모델

# %% [markdown]
# - GridSearch를 이용해 최고의 모델을 뽑아 비교한다.

# %%
params = {
    'max_depth' : [6, 8, 10],           # depth 설정
    'n_estimators' : [50, 100, 200],    # tree의 개수
    'min_samples_leaf' : [8, 12],       # 각 결과 데이터의 최소 개수
    'min_samples_split' : [8, 12]       # 분할의 최소 개수
}
rfr_clf = RandomForestRegressor(random_state=13, n_jobs=-1)
grid_cv = GridSearchCV(rfr_clf, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestRegressor(n_jobs=-1, random_state=13),
#              n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10], 'min_samples_leaf': [8, 12],
#                          'min_samples_split': [8, 12],
#                          'n_estimators': [50, 100, 200]})

# %%
# 결과 정리
cv_results_df = pd.DataFrame(grid_cv.cv_results_)
target_col = ['rank_test_score', 'mean_test_score', 'param_n_estimators', 'param_max_depth']
cv_results_df[target_col].sort_values(by='rank_test_score').head()
# Out:
#     rank_test_score  mean_test_score param_n_estimators param_max_depth
# 27                1         0.694591                 50              10
# 24                1         0.694591                 50              10
# 0                 3         0.694536                 50               6
# 3                 3         0.694536                 50               6
# 15                5         0.694477                 50               8

# %%
grid_cv.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 8,
#  'min_samples_split': 8,
#  'n_estimators': 50}

# %% [markdown]
# - GridSearch로 알아낸 최고의 모델로 예측을 시도한다.
# - **LinearRegression의 결과보다 좋은 결과를 획득하였다.**

# %%
best_rfr_clf = grid_cv.best_estimator_

pred_tr = best_rfr_clf.predict(X_train)
pred_test = best_rfr_clf.predict(X_test)
rmse_tr = (np.sqrt(mean_squared_error(y_train, pred_tr)))
rmse_test = (np.sqrt(mean_squared_error(y_test, pred_test)))

print('RMSE of Train Data : {}'.format(rmse_tr))
print('RMSE of Test Data : {}'.format(rmse_test))
# Out:
# RMSE of Train Data : 749.7392867099799
# RMSE of Test Data : 1005.376789876842

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, pred_test)
plt.xlabel('Real Count(1000명)')
plt.ylabel('Predicted Count(1000명)')
plt.title('Real vs Predicted')
plt.grid(True)
plt.plot([0, 15000], [0, 15000], 'r')
plt.show()

# %% [markdown]
# ### 3. 2020년 데이터 적용

# %% [markdown]
# #### 2020년 데이터 예측

# %% [markdown]
# - 2개의 모델을 비교했을 때 랜덤 포레스트 회귀 모델이 높은 성능을 냈다.
# - 높은 성능을 낸 `best_rfr_clf`를 이용해 2020년 데이터를 예측한다.

# %%
# 변수, 라벨 분리
X_2020 = movie_2020.drop(not_used, axis=1)
y_2020 = movie_2020['전국관객수'] / 1000

X_2020.shape, y_2020.shape
# Out:
# ((234, 39), (234,))

# %% [markdown]
# - 모델 예측 및 평가
#   - RMSE 값이 작았던 랜덤 포레스트 회귀 모델을 사용해 예측해본다.

# %%
pred_2020 = best_rfr_clf.predict(X_2020)
rmse_2020 = (np.sqrt(mean_squared_error(y_2020, pred_2020)))

print('RMSE of 2020 Data : {}'.format(rmse_2020))
# Out:
# RMSE of 2020 Data : 904.1762262284616

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_2020, pred_2020)
plt.xlabel('Real Count(1000명)')
plt.ylabel('Predicted Count(1000명)')
plt.title('Real vs Predicted')
plt.grid(True)
plt.plot([0, 6000], [0, 6000], 'r')
plt.show()

# %% [markdown]
# #### 실제값과 예측값 비교

# %% [markdown]
# - 예측 결과를 `movie_2020`에 추가하여 비교해본다.

# %%
movie_predict = movie_2020[not_used]
# 1000으로 나눈 예측값이므로 다시 곱해준다.
movie_predict['예측관객수'] = (pred_2020 * 1000).astype('int')

# %%
movie_predict.head()
# Out:
#              영화명        감독     주연배우   평가자수                  배급사        개봉일  \
# 84       남산의 부장들       우민호      이병헌  18168               (주)쇼박스 2020-01-22
# 97   다만 악에서 구하소서       홍원찬      황정민  21397            (주)씨제이이엔엠 2020-08-05
# 113           반도       연상호      강동원  31323  (주)넥스트엔터테인먼트월드(NEW) 2020-07-15
# 204          히트맨       최원섭      권상우  12619                   롯데 2020-01-22
# 243           테넷  크리스토퍼 놀란  로버트 패틴슨  10876        워너브러더스 코리아(주) 2020-08-26
#
#        전국관객수    예측관객수
# 84   4750104  6763769
# 97   4352669  8810931
# 113  3812080  8569370
# 204  2406232  1430899
# 243  1998987  7501710

# %% [markdown]
# - 전국 관객수와 예측 관객수 히스토그램

# %%
fig = px.histogram(movie_predict, x='전국관객수')
fig.show()

# %%
fig = px.histogram(movie_predict, x='예측관객수')
fig.show()

# %% [markdown]
# #### 결과

# %% [markdown]
# - 2011년 ~ 2019년 데이터로 예측한 결과는 실제 관객수가 커질수록 예측 관객수가 적은 경우가 대부분이였다.
# - 2020년 데이터로 예측한 결과는 관객수가 적었던 영화를 제외하고는 실제 관객수가 커질수록 예측 관객수가 높은 값을 기록하였다.
# - 이러한 차이가 코로나19의 영향이라고 판단하였다.
